# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
# !pip install ipyleaflet --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# Requirement already satisfied: getorg in c:\users\alexs\anaconda3\lib\site-packages (0.3.1)
# Requirement already satisfied: geopy in c:\users\alexs\anaconda3\lib\site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in c:\users\alexs\anaconda3\lib\site-packages (from getorg) (2.8.1)
# Requirement already satisfied: retrying in c:\users\alexs\anaconda3\lib\site-packages (from getorg) (1.4.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\alexs\anaconda3\lib\site-packages (from geopy->getorg) (2.1)
# Requirement already satisfied: pynacl>=1.4.0 in c:\users\alexs\anaconda3\lib\site-packages (from pygithub->getorg) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in c:\users\alexs\anaconda3\lib\site-packages (from pygithub->getorg) (2.32.3)
# Requirement already satisfied: pyjwt>=2.4.0 in c:\users\alexs\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.8.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\alexs\anaconda3\lib\site-packages (from pygithub->getorg) (4.14.1)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\alexs\anaconda3\lib\site-packages (from pygithub->getorg) (2.5.0)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\alexs\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (43.0.0)
# Requirement already satisfied: cffi>=1.4.1 in c:\users\alexs\anaconda3\lib\site-packages (from pynacl>=1.4.0->pygithub->getorg) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alexs\anaconda3\lib\site-packages (from requests>=2.14.0->pygithub->getorg) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\alexs\anaconda3\lib\site-packages (from requests>=2.14.0->pygithub->getorg) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alexs\anaconda3\lib\site-packages (from requests>=2.14.0->pygithub->getorg) (2025.8.3)
# Requirement already satisfied: pycparser in c:\users\alexs\anaconda3\lib\site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->getorg) (2.21)
# Requirement already satisfied: ipyleaflet in c:\users\alexs\anaconda3\lib\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.5.0 in c:\users\alexs\anaconda3\lib\site-packages (from ipyleaflet) (0.8.2)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\alexs\anaconda3\lib\site-packages (from ipyleaflet) (7.8.1)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in c:\users\alexs\anaconda3\lib\site-packages (from ipyleaflet) (0.20.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in c:\users\alexs\anaconda3\lib\site-packages (from ipyleaflet) (0.2.3)
# Requirement already satisfied: xyzservices>=2021.8.1 in c:\users\alexs\anaconda3\lib\site-packages (from ipyleaflet) (2022.9.0)
# Requirement already satisfied: jinja2>=3 in c:\users\alexs\anaconda3\lib\site-packages (from branca>=0.5.0->ipyleaflet) (3.1.4)
# Requirement already satisfied: comm>=0.1.3 in c:\users\alexs\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\alexs\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\alexs\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in c:\users\alexs\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\alexs\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (8.27.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\alexs\anaconda3\lib\site-packages (from ipywidgets<9,>=7.6.0->ipyleaflet) (1.0.0)
# Requirement already satisfied: decorator in c:\users\alexs\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\alexs\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\alexs\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\alexs\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\alexs\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\alexs\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.0)
# Requirement already satisfied: colorama in c:\users\alexs\anaconda3\lib\site-packages (from ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alexs\anaconda3\lib\site-packages (from jinja2>=3->branca>=0.5.0->ipyleaflet) (2.1.3)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\alexs\anaconda3\lib\site-packages (from widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (7.2.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\alexs\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\alexs\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\alexs\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in c:\users\alexs\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\alexs\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\alexs\anaconda3\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (6.4.1)
# Requirement already satisfied: wcwidth in c:\users\alexs\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.5)
# Requirement already satisfied: executing in c:\users\alexs\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\alexs\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\alexs\anaconda3\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (0.2.2)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (7.4.0)
# Requirement already satisfied: packaging>=22.0 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (24.1)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.14.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\alexs\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\alexs\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in c:\users\alexs\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\alexs\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.2.0)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\alexs\anaconda3\lib\site-packages (from jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (75.1.0)
# Requirement already satisfied: babel>=2.10 in c:\users\alexs\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\alexs\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\alexs\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\alexs\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.32.3)
# Requirement already satisfied: six in c:\users\alexs\anaconda3\lib\site-packages (from asttokens->stack-data->ipython>=4.0.0->ipywidgets<9,>=7.6.0->ipyleaflet) (1.16.0)
# Requirement already satisfied: idna>=2.8 in c:\users\alexs\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alexs\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\alexs\anaconda3\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\alexs\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2024.1)
# Requirement already satisfied: certifi in c:\users\alexs\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\alexs\anaconda3\lib\site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\alexs\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.14.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\alexs\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (1.6.7)
# Requirement already satisfied: nest-asyncio in c:\users\alexs\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (1.6.0)
# Requirement already satisfied: psutil in c:\users\alexs\anaconda3\lib\site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (5.9.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\alexs\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\alexs\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\alexs\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\alexs\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\alexs\anaconda3\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\alexs\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\alexs\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\alexs\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\alexs\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\alexs\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\alexs\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\alexs\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\alexs\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\alexs\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\alexs\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\alexs\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.5.0)
# Requirement already satisfied: webencodings in c:\users\alexs\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\alexs\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\alexs\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\alexs\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.1)
# Requirement already satisfied: uri-template in c:\users\alexs\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\alexs\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\alexs\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\alexs\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.5)
# Requirement already satisfied: pycparser in c:\users\alexs\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\alexs\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook>=4.4.1->widgetsnbextension~=3.6.6->ipywidgets<9,>=7.6.0->ipyleaflet) (1.2.3)

# %%
g = glob.glob("*.md")

# %%
geocoder = Nominatim(user_agent="alexsietsema@math.ucla.edu")
location_dict = {}
location = ""
permalink = ""
title = ""

# %%
import os
os.chdir(r'C:\Users\alexs\Projects\alexandersietsema.github.io\_talks')
for file in g:
    with open(file, 'r',encoding='utf-8') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# East Lansing, MI
#  East Lansing, Ingham County, Michigan, United States
# East Lansing, MI
#  East Lansing, Ingham County, Michigan, United States
# East Lansing, MI
#  East Lansing, Ingham County, Michigan, United States
# East Lansing, MI
#  East Lansing, Ingham County, Michigan, United States
# East Lansing, MI
#  East Lansing, Ingham County, Michigan, United States
# East Lansing, MI
#  East Lansing, Ingham County, Michigan, United States
# East Lansing, MI
#  East Lansing, Ingham County, Michigan, United States
# Baltimore, MD
#  Baltimore, Maryland, United States
# Los Angeles, CA
#  Los Angeles, Los Angeles County, California, United States
# Los Angeles, CA
#  Los Angeles, Los Angeles County, California, United States
# Pacific Grove, CA
#  Pacific Grove, Monterey County, California, 93950, United States

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'
