# %% [markdown]
# # Web Scraping Ultimate Season Data
#
# Before we start with code, a recap of the goal: we are hoping to make some spreadsheets to summarize game data for major Ultimate tournaments. To do this, we plan to use the website Ultiarchive to get a list of major tournaments, and use the corresponding links to the USAU website to get the actual game information.
#
# For example, if we wanted to get the 2019 Club Open National Championship information, we would:
#
#     1. Visit https://ultiarchive.com/years/2019
#     2. Find the club open page here: https://ultiarchive.com/tournaments/national-championships-club/years/2019/divisions/club-open
#     3.Visit the USAU link at the top of the page to get to the USAU website page for the tournament https://play.usaultimate.org/events/USA-Ultimate-National-Championships-2019/schedule/Men/Club-Men/
#     4. Use this page to get game data.
#
#
# First of all, why do it this way? The Ultiarchive list is great because it only includes USAU sanctioned tournaments, which are only a small subset of all the tournaments on the USAU website. It *is* possible to find them on USAU directly, but it's difficult since it relies on the built-in event search engine. Using Ultiarchive we have a pretty simple (if a bit long) pipeline to get to the tournament data we want.
#
# Second: the Ultiarchive pages also have the tournament results. Why not just pull the results from there? The reason is that the Ultiarchive pages are populated with Javascript which, as we will see below, are difficult to work with. The USAU pages are hard-coded, so we can use BeautifulSoup to work with the source code to get the information we need.
#
# ###### A general note: the way this code is designed/structured is just what I've figured out through a combination of Google and trial and error. I'm sure there are better ways to do everything here, but this works at least!

# %% [markdown]
# Finally, for people unfamiliar with HTML structure, here are the basics: every piece of information on a webpage is stored in a tag, which is marked which is either standalone `<tag>` or marked with an open tag `<tag>` and a close tag `</tag>`. There can be information (attributes) stored in the tag itself, or in child tags. For example, we might have:
#
#
# `<div class='center'>`
# `<img src="image.jpg">` Some text.
# `</div>`
#
# where the `<div>` tag has a `class` attribute, but also has an `<img>` child with `src` attribute. The div tag is a container, so it has the close tag too (`</div>`). If we wanted to get the text inside the tag, we would call the `.text` attribute of the `<div>` tag.
#
# Our job here will essentially be to look at the source code and figure out how the page is structured with these tags in order to figure out which ones we need to get data from and which we can ignore. This is what BeautifulSoup does! See below.

# %% [markdown]
# ## 0 Basics

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup, Comment
# BeautifulSoup (hereafter BS) and requests are the two main packages for normal web scraping.
# requests mainly actually gets you the source data, and BeautifulSoup lets
# you actually work with it?
import urllib3
import urllib.request
import matplotlib.pyplot as plt
import seaborn as sns
# Seaborn is a plotting package that can make things look nicer than Matplotlib, but is most useful
# since it works nicely with Pandas dataframes. I'm including it here as a standard import, at time
# of writing I'm not sure if it will be used or not. It's a nice thing to have though!

import itertools as it
import more_itertools as mit
# Not sure if we'll need either of these, but again, standard imports.

import json
import re
# This is the regex package. For those unfamiliar, regex is a "language" for
# very specific text searching and extraction. Check out https://regexone.com/
# for a tutorial / explanation. 
import io
import math
import time
import cProfile
from pprint import pprint
# Will be useful for demonstration
from tqdm.notebook import tqdm
# Will make nice progress bars

import selenium
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
# I am using Chrome here, there are other supported browsers out there too.
# I think Firefox is actually the more common one for this

chrome_options = Options()
chrome_options.add_argument("--headless")
# Headless stops a browser from being visibly opened on your computer.

driver = webdriver.Chrome(options=chrome_options, 
              executable_path=r"C:\Users\alexs\Projects\lls\chromedriver.exe")

# You will have to download the chromedriver.exe file and change this path to
# point at it.

# %% [markdown]
# ## 0.1 The general strategy

# %% [markdown]
# Here is the basic step-by-step process we will follow for reading a season:
#
#     0. Input a year and competition division (open, women's, mixed)
#     1. Visit the Ultiarchive page for that season and get a list of links corresponding to each tournament
#     2. For each tournament, parse that page to visit the USAU page.
#     3. Parse the USAU page to get each game type (pool play or bracket play)
#     4. For each tournament stage, parse the page to get each game subtype (pool A/B/..., 1st place/3rd place/... bracket)
#     6. For each game subtype, get each bracket position (quarter/semi/finals)
#     7. For each bracket position, get the corresponding game.
#     8. For each game, parse the game to get the information we want
#     9. Put the game information together into a Pandas dataframe row
#
# We will have functions for each of these steps, and other utility functions to handle the lower-level processes. Because of this, it can sometimes be a bit tough to understand how all of these pieces fit together, but keeping this step-by-step picture in the back of your mind should help.

# %% [markdown]
# ## 1 Dealing with Javascript pages

# %% [markdown]
# Most of the fun stuff will be with BeautifulSoup as we will see below, but there is a wrinkle as mentioned above: Ultiarchive.com is a javascript-based website, so we can't use any of the normal BeautifulSoup techniques to scrape it. Below is the entire source of the webpage for 2019 tournaments:

# %% [raw]
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta charset="utf-8" />
#     <title>Ultiarchive</title>
#     <base href="/" />
#
#     <meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=5,minimum-scale=1" />
#     <meta name="Description" content="Past, current, and future ultimate firsbee tournaments" />
#     <link rel="icon" type="image/x-icon" href="favicon.png" />
#     <link rel="manifest" href="manifest.webmanifest" />
#     <link rel="preconnect" href="https://firestore.googleapis.com" />
#     <meta name="theme-color" content="#1976d2" />
#     <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500" rel="stylesheet" />
#     <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet" />
#     <link href="https://cdnjs.cloudflare.com/ajax/libs/flag-icon-css/2.9.0/css/flag-icon.min.css" rel="stylesheet" />
#   <link rel="stylesheet" href="styles.98a99bf1902d6c02d16b.css"></head>
#   <body>
#     <app-root></app-root>
#     <noscript>Please enable JavaScript to continue using this application.</noscript>
#   <script src="runtime-es2015.d13ed9c62e72f74d37ca.js" type="module"></script><script src="runtime-es5.d13ed9c62e72f74d37ca.js" nomodule defer></script><script src="polyfills-es5.64948ba7a3f8b53ec9dd.js" nomodule defer></script><script src="polyfills-es2015.511162d609f0ab5fde87.js" type="module"></script><script src="main-es2015.f8e362cc1b7be37954f0.js" type="module"></script><script src="main-es5.f8e362cc1b7be37954f0.js" nomodule defer></script></body>
# </html>

# %% [markdown]
# We can see that there isn't actually any information there, just some calls to Javascript at the bottom. Requests and BS cannot actually get the result of the Javascript, so we use a package called selenium instead. Selenium more or less uses a regular browser to access the page, so the Javascript gets loaded normally.

# %%
def jspage_to_soup(url, scroll=True):
    """Visit a JavaScript page and convert it into a soup."""
    # This is all selenium code!
    chrome_options = Options()
    chrome_options.add_argument("--headless")

    # Headless stops a browser from being visibly opened on your computer.

    driver = webdriver.Chrome(options=chrome_options, 
                  executable_path=r"C:\Users\alexs\Projects\lls\chromedriver.exe")

    # You will have to download the chromedriver.exe file and change this path to
    # point at it.
   
    driver.get(url)
    # Visit the page with the driver!

    time.sleep(1.5)
    # !!! We need to give the page time to load!
    if scroll:
        for i in range(20):
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);\
                                  var lenOfPage=document.body.scrollHeight;\
                                  return lenOfPage;")
            time.sleep(1)
            # This process literally scrolls the page all the way down to make sure that all of the content
            # gets read and stored. We won't always need to do this (see below), so we add an option to control it.
    
    data = driver.page_source.encode("utf-8")
    # Takes the driver response and grabs the page source code including the javascript. This puts things in
    # a form that BS can handle.
    
    soup = BeautifulSoup(data, 'html.parser')
    # Makes the soup object!
    # Note: a soup object is essentially a version of the source code that has the nested tag HTML structure the
    # same way as if you look at a page in a browser inspector.
    return soup

# %% [markdown]
# To reiterate: Selenium actually loads the webpage using a normal browser, so we need to explicitly give it time to load!

# %% [markdown]
# ## 2 Getting the tournament links (fun with HTML)

# %% [markdown]
# Recall that at this step we want to find links to the Ultiarchive pages for **USAU** tournaments. That USAU part is a big caveat: we need to ignore some of the tournaments on this page!
#
#
# At this point, we want to describe the process of figuring out how to actually get that information of soup that we generated above. To start with: what does that soup object actually contain? Let's take a look at the tournaments from 2019 (https://ultiarchive.com/years/2019):

# %%
# (this will take a while to load!)
soup = jspage_to_soup("https://ultiarchive.com/years/2019")
soup
# Out:
# <html lang="en"><head>
# <meta charset="utf-8"/>
# <title>Tournaments</title>
# <base href="/"/>
# <meta content="width=device-width,initial-scale=1,maximum-scale=5,minimum-scale=1" name="viewport"/>
# <meta content="Past, current, and future ultimate firsbee tournaments" name="Description"/>
# <link href="favicon.png" rel="icon" type="image/x-icon"/>
# <link href="manifest.webmanifest" rel="manifest"/>
# <link href="https://firestore.googleapis.com" rel="preconnect"/>
# <meta content="#337ab7" name="theme-color"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/flag-icon-css/2.9.0/css/flag-icon.min.css" rel="stylesheet"/>
# <link href="styles.98a99bf1902d6c02d16b.css" rel="stylesheet"/><script charset="utf-8" src="6-es2015.19e90bb1f4121cbac358.js"></script><style>.light-theme[_ngcontent-jlt-c25]{color:#333}.light-theme[_ngcontent-jlt-c25]   .content[_ngcontent-jlt-c25]{position:relative;z-index:1;padding:45px 10px 10px}.dark-theme[_ngcontent-jlt-c25]{color:#d7dadc}.dark-theme[_ngcontent-jlt-c25]   .content[_ngcontent-jlt-c25]{position:relative;z-index:1;padding:45px 10px 10px}#blur[_ngcontent-jlt-c25]{-webkit-transition:filter .2s linear;transition:.2s filter linear;-webkit-filter:blur(0);filter:blur(0)}</style><style>.light-theme[_nghost-jlt-c14], .light-theme   [_nghost-jlt-c14]{position:fixed;top:0;left:0;right:0;height:45px;background:#337ab7;z-index:22}.light-theme[_nghost-jlt-c14]   a[_ngcontent-jlt-c14], .light-theme   [_nghost-jlt-c14]   a[_ngcontent-jlt-c14]{display:inline-block;color:#fff;text-decoration:none;font-size:24px;vertical-align:middle;position:absolute;top:8px;left:10px}.dark-theme[_nghost-jlt-c14], .dark-theme   [_nghost-jlt-c14]{position:fixed;top:0;left:0;right:0;height:45px;background:#0a3b67;z-index:22}.dark-theme[_nghost-jlt-c14]   a[_ngcontent-jlt-c14], .dark-theme   [_nghost-jlt-c14]   a[_ngcontent-jlt-c14]{display:inline-block;color:#fff;text-decoration:none;font-size:24px;vertical-align:middle;position:absolute;top:8px;left:10px}</style><style>h1[_ngcontent-jlt-c24]   .small[_ngcontent-jlt-c24], h2[_ngcontent-jlt-c24]   .small[_ngcontent-jlt-c24], h3[_ngcontent-jlt-c24]   .small[_ngcontent-jlt-c24], h4[_ngcontent-jlt-c24]   .small[_ngcontent-jlt-c24], h5[_ngcontent-jlt-c24]   .small[_ngcontent-jlt-c24], h6[_ngcontent-jlt-c24]   .small[_ngcontent-jlt-c24]{font-size:.8em;opacity:.7;font-weight:400}</style><style>.light-theme[_nghost-jlt-c13] > span[_ngcontent-jlt-c13], .light-theme   [_nghost-jlt-c13] > span[_ngcontent-jlt-c13]{height:25px;width:50px;background:#fafafa;border-radius:2px;position:absolute;top:10px;right:10px;cursor:pointer}.light-theme[_nghost-jlt-c13] > span[_ngcontent-jlt-c13] > span[_ngcontent-jlt-c13], .light-theme   [_nghost-jlt-c13] > span[_ngcontent-jlt-c13] > span[_ngcontent-jlt-c13]{position:absolute;top:2px;left:2px;right:27px;bottom:2px;background:#337ab7;-webkit-transition:.3s;transition:all .3s;border-radius:2px;overflow:hidden}.light-theme[_nghost-jlt-c13] > span[_ngcontent-jlt-c13] > span[_ngcontent-jlt-c13]:after, .light-theme   [_nghost-jlt-c13] > span[_ngcontent-jlt-c13] > span[_ngcontent-jlt-c13]:after{content:"";position:absolute;top:50%;left:50%;margin-left:-6.25px;margin-top:-6.25px;width:12.5px;height:12.5px;background:#ff0;border-radius:50%;z-index:1}.light-theme[_nghost-jlt-c13] > span[_ngcontent-jlt-c13] > span[_ngcontent-jlt-c13]:before, .light-theme   [_nghost-jlt-c13] > span[_ngcontent-jlt-c13] > span[_ngcontent-jlt-c13]:before{content:"";position:absolute;top:50%;left:50%;margin-left:-8.25px;margin-top:-7.25px;width:0;height:0;-webkit-transition:width .3s,height .3s;transition:width .3s,height .3s;background:#337ab7;border-radius:50%;z-index:2}.light-theme[_nghost-jlt-c13] > span.dark-theme[_ngcontent-jlt-c13] > span[_ngcontent-jlt-c13], .light-theme   [_nghost-jlt-c13] > span.dark-theme[_ngcontent-jlt-c13] > span[_ngcontent-jlt-c13]{left:27px;right:2px}.light-theme[_nghost-jlt-c13] > span.dark-theme[_ngcontent-jlt-c13] > span[_ngcontent-jlt-c13]:after, .light-theme   [_nghost-jlt-c13] > span.dark-theme[_ngcontent-jlt-c13] > span[_ngcontent-jlt-c13]:after{background:#fff}.light-theme[_nghost-jlt-c13] > span.dark-theme[_ngcontent-jlt-c13] > span[_ngcontent-jlt-c13]:before, .light-theme   [_nghost-jlt-c13] > span.dark-theme[_ngcontent-jlt-c13] > span[_ngcontent-jlt-c13]:before{width:12.5px;height:12.5px}.dark-theme[_nghost-jlt-c13] > span[_ngcontent-jlt-c13], .dark-theme   [_nghost-jlt-c13] > span[_ngcontent-jlt-c13]{height:25px;width:50px;background:#212121;border-radius:2px;position:absolute;top:10px;right:10px;cursor:pointer}.dark-theme[_nghost-jlt-c13] > span[_ngcontent- ...
# <body class="light-theme">
# <app-root _nghost-jlt-c25="" ng-version="9.0.0-rc.8"><div _ngcontent-jlt-c25="" class="light-theme"><header _ngcontent-jlt-c25=""><app-header _ngcontent-jlt-c25="" _nghost-jlt-c14=""><a _ngcontent-jlt-c14="" href="/">Ultiarchive</a><app-theme-toggle _ngcontent-jlt-c14="" _nghost-jlt-c13=""><span _ngcontent-jlt-c13="" class="light-theme"><span _ngcontent-jlt-c13=""></span></span></app-theme-toggle></app-header></header><div _ngcontent-jlt-c25="" id="blur"><main _ngcontent-jlt-c25=""><div _ngcontent-jlt-c25="" class="content"><app-page-header _ngcontent-jlt-c25="" _nghost-jlt-c24=""><h1 _ngcontent-jlt-c24="" class="ng-star-inserted"> Tournaments <!-- --></h1><!-- --><!-- --><app-menu _ngcontent-jlt-c24="" _nghost-jlt-c23=""><button _ngcontent-jlt-c23="" aria-haspopup="true" class="mat-button mat-button-base mat-menu-trigger ng-star-inserted" mat-button=""><span class="mat-button-wrapper"> 2019 <i _ngcontent-jlt-c23="" class="material-icons ng-star-inserted"> arrow_drop_down </i><!-- --></span><div class="mat-button-ripple mat-ripple" matripple=""></div><div class="mat-button-focus-overlay"></div></button><!-- --><mat-menu _ngcontent-jlt-c23="" class="ng-tns-c21-0 ng-star-inserted"><!-- --></mat-menu><!-- --><!-- --><!-- --><!-- --><!-- --></app-menu></app-page-header><router-outlet _ngcontent-jlt-c25=""></router-outlet><app-years _nghost-jlt-c27="" class="ng-star-inserted"><app-tournament-list _ngcontent-jlt-c27="" _nghost-jlt-c26=""><div _ngcontent-jlt-c26="" class="container"><table _ngcontent-jlt-c26=""><tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 15<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Southwest College Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/southwest-college-regionals-college/years/2019/divisions/college-mixed">College Mixed</a><!-- --><!-- --></td></tr><tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 9<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> North College Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/north-college-regionals-college/years/2019/divisions/college-mixed">College Mixed</a><!-- --><!-- --></td></tr><tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 8<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> South College Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/south-college-regionals-college/years/2019/divisions/college-mixed">College Mixed</a><!-- --><!-- --></td></tr><tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 8<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Northwest College Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/northwest-college-regionals-college/years/2019/divisions/college-mixed">College Mixed</a><!-- --><!-- --></td></tr><tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 8<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> North Carolina High School Div 1 Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/north-carolina-high-school-div-1-championships-youth/years/2019/divisions/youth-girls">Youth Girls</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/north-carolina-high-school-div-1-championships-youth/years/2019/divisions/youth-open">Youth Open</a><!-- --><!-- --></td></tr><tr _ngcontent-jlt-c26="" class="ng-star-inserte ...
# <noscript>Please enable JavaScript to continue using this application.</noscript>
# <script src="runtime-es2015.d13ed9c62e72f74d37ca.js" type="module"></script><script defer="" nomodule="" src="runtime-es5.d13ed9c62e72f74d37ca.js"></script><script defer="" nomodule="" src="polyfills-es5.64948ba7a3f8b53ec9dd.js"></script><script src="polyfills-es2015.511162d609f0ab5fde87.js" type="module"></script><script src="main-es2015.f8e362cc1b7be37954f0.js" type="module"></script><script defer="" nomodule="" src="main-es5.f8e362cc1b7be37954f0.js"></script>
# </body></html>

# %% [markdown]
# This is a lot. To make sense of all of thise code, we just have to carefully look for the information we wnat and figure out how it is stored. In our case, we see that the rows of the table are stored inside of `<tr>` tags. Below we have bolded the opening and closing tag of such a row:
#
# `/college-womens">College Women's</a><!-- --><!-- --></td></tr>`**`<tr _ngcontent-jua-c26="" class="ng-star-inserted">`**`<td _ngcontent-jua-c26=""> Jan 25<!-- --></td><td _ngcontent-jua-c26=""><span _ngcontent-jua-c26="" class="tournament-type usau">usau</span> Santa Barbara Invite </td><td _ngcontent-jua-c26=""><!-- --><a _ngcontent-jua-c26="" class="ng-star-inserted" href="/tournaments/santa-barbara-invite-college/years/2019/divisions/college-open">College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jua-c26="" class="ng-star-inserted" href="/tournaments/santa-barbara-invite-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td>`**`</tr>`**`<tr _ngcontent-jua-c26="" class="ng-star-inserted"><td _ngcontent-`
#
# Looking inside the tag, we can see that the information we want is there! Using BS, we can search for all instances of just those tags:

# %%
soup.find_all('tr') # searches for tags with the 'tr' attribute.
# Out:
# [<tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 15<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Southwest College Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/southwest-college-regionals-college/years/2019/divisions/college-mixed">College Mixed</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 9<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> North College Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/north-college-regionals-college/years/2019/divisions/college-mixed">College Mixed</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 8<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> South College Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/south-college-regionals-college/years/2019/divisions/college-mixed">College Mixed</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 8<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Northwest College Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/northwest-college-regionals-college/years/2019/divisions/college-mixed">College Mixed</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 8<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> North Carolina High School Div 1 Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/north-carolina-high-school-div-1-championships-youth/years/2019/divisions/youth-girls">Youth Girls</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/north-carolina-high-school-div-1-championships-youth/years/2019/divisions/youth-open">Youth Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 8<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> East College Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/east-college-regionals-college/years/2019/divisions/college-mixed">College Mixed</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 8<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Colorado State Fall Championships Fun </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/colorado-state-fall-championships-fun-junior/years/2019/divisions/junior-open">Junior Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 8<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Colorado High School Div 2 Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/colorado-high-school-div-2-championships-junior/years/2019/divisions/junior-open">Junior Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 8<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Colorado High School Div 1 Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/colorado-high-school-div-1-championships-junior/years/2019/divisions/junior-open">Junior Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Utah High School Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/utah-high-school-championships-junior/years/2019/divisions/junior-open">Junior Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 4<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type wfdf">wfdf</span> Pan American Ultimate Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/pan-american-ultimate-championships-masters/years/2019/divisions/masters-mixed">Masters Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/pan-american-ultimate-championships-masters/years/2019/divisions/masters-open">Masters Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 4<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type wfdf">wfdf</span> Pan American Ultimate Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/pan-american-ultimate-championships-grand/years/2019/divisions/grand-masters-open">Grand Masters Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 4<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type wfdf">wfdf</span> Pan American Ultimate Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/pan-american-ultimate-championships-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/pan-american-ultimate-championships-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/pan-american-ultimate-championships-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 2<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Colorado High School Qualifiers West </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/colorado-high-school-qualifiers-west-junior/years/2019/divisions/junior-open">Junior Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 2<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Blue Ridge Finale </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/blue-ridge-finale-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Nov 1<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Northeast College Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/northeast-college-regionals-college/years/2019/divisions/college-mixed">College Mixed</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Oct 26<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Red Tide Ultimate Clambake </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/red-tide-ultimate-clambake-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/red-tide-ultimate-clambake-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/red-tide-ultimate-clambake-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Oct 26<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> North Carolina Youth Fall Cup </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/north-carolina-youth-fall-cup-junior/years/2019/divisions/junior-open">Junior Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Oct 26<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> New York Youth Fall Cup </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/new-york-youth-fall-cup-junior/years/2019/divisions/junior-open">Junior Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Oct 24<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> National Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/national-championships-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/national-championships-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/national-championships-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Oct 19<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> The Lobster Pot </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/the-lobster-pot-college/years/2019/divisions/college-mixed">College Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/the-lobster-pot-college/years/2019/divisions/college-open">College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/the-lobster-pot-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Oct 19<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Ohio High School Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/ohio-high-school-championships-junior/years/2019/divisions/junior-open">Junior Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Oct 13<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Maine High School Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/maine-high-school-championships-junior/years/2019/divisions/junior-open">Junior Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Oct 5<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Just Plain Nasty </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/just-plain-nasty-college/years/2019/divisions/college-open">College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/just-plain-nasty-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Oct 5<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Fall Dick And Jane </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/fall-dick-and-jane-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 28<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Fusion </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/fusion-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 21<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Southwest Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/southwest-regionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/southwest-regionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/southwest-regionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 21<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Southeast Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/southeast-regionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/southeast-regionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/southeast-regionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 21<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> South Central Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/south-central-regionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/south-central-regionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/south-central-regionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 21<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Northwest Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/northwest-regionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/northwest-regionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/northwest-regionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 21<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Northeast Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/northeast-regionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/northeast-regionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/northeast-regionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 21<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> North Central Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/north-central-regionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/north-central-regionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/north-central-regionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 21<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Mid Atlantic Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/mid-atlantic-regionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/mid-atlantic-regionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/mid-atlantic-regionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 21<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Great Lakes Regionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/great-lakes-regionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/great-lakes-regionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/great-lakes-regionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 8<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Nor Cal Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/nor-cal-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/nor-cal-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/nor-cal-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> West Plains Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/west-plains-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/west-plains-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/west-plains-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> West New England Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/west-new-england-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/west-new-england-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/west-new-england-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Washington Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/washington-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/washington-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/washington-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Upstate New York Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/upstate-new-york-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/upstate-new-york-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/upstate-new-york-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Texas Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/texas-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/texas-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/texas-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> So Cal Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/so-cal-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/so-cal-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/so-cal-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Rocky Mountain Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/rocky-mountain-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/rocky-mountain-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/rocky-mountain-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Ozarks Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/ozarks-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/ozarks-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Oregon Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/oregon-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/oregon-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Northwest Plains Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/northwest-plains-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/northwest-plains-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/northwest-plains-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> North Carolina Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/north-carolina-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/north-carolina-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/north-carolina-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Metro New York Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/metro-new-york-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/metro-new-york-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/metro-new-york-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Gulf Coast Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/gulf-coast-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/gulf-coast-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/gulf-coast-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Founders Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/founders-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/founders-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/founders-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Florida Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/florida-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/florida-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/florida-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> East Plains Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/east-plains-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/east-plains-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/east-plains-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> East New England Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/east-new-england-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/east-new-england-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/east-new-england-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> East Coast Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/east-coast-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/east-coast-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/east-coast-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Central Plains Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/central-plains-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/central-plains-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/central-plains-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Capital Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/capital-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/capital-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/capital-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Sep 7<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Big Sky Sectionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/big-sky-sectionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/big-sky-sectionals-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/big-sky-sectionals-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 31<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Tct Pro Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/tct-pro-championships-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/tct-pro-championships-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/tct-pro-championships-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 31<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Labor Day Recreational </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/labor-day-recreational-club/years/2019/divisions/club-open">Club Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 24<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> The Incident Age Of Ultimatron </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/the-incident-age-of-ultimatron-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/the-incident-age-of-ultimatron-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/the-incident-age-of-ultimatron-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 24<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Ski Town Classic </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/ski-town-classic-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/ski-town-classic-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/ski-town-classic-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 24<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Indy Invite </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/indy-invite-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/indy-invite-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/indy-invite-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 24<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Fcs Invite </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/fcs-invite-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/fcs-invite-club/years/2019/divisions/club-open">Club Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 17<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Tct Elite Select Challenge </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/tct-elite-select-challenge-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/tct-elite-select-challenge-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/tct-elite-select-challenge-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 17<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Sanctionals </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/sanctionals-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 17<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Northwest Fruit Bowl </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/northwest-fruit-bowl-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 17<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Mudbowl </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/mudbowl-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/mudbowl-club/years/2019/divisions/club-open">Club Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 17<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Hootie On The Hill </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/hootie-on-the-hill-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/hootie-on-the-hill-club/years/2019/divisions/club-open">Club Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 17<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Cooler Classic </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/cooler-classic-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/cooler-classic-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/cooler-classic-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 17<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Chowdafest </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/chowdafest-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 15<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type uc">uc</span> Canadian Ultimate Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/canadian-ultimate-championships-masters/years/2019/divisions/masters-mixed">Masters Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/canadian-ultimate-championships-masters/years/2019/divisions/masters-open">Masters Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/canadian-ultimate-championships-masters/years/2019/divisions/masters-womens">Masters Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 15<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type uc">uc</span> Canadian Ultimate Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/canadian-ultimate-championships-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/canadian-ultimate-championships-club/years/2019/divisions/club-open">Club Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/canadian-ultimate-championships-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 11<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type uc">uc</span> Canadian Ultimate Championships </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/canadian-ultimate-championships-junior/years/2019/divisions/junior-open">Junior Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/canadian-ultimate-championships-junior/years/2019/divisions/junior-women">Junior Women</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 11<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Cuda Round Robin </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/cuda-round-robin-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 10<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Nucci S Cup </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/nucci-s-cup-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/nucci-s-cup-club/years/2019/divisions/club-open">Club Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Aug 10<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Hodown Showdown G O A T </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/hodown-showdown-g-o-a-t-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/hodown-showdown-g-o-a-t-club/years/2019/divisions/club-womens">Club Women's</a><!-- --><!-- --></td></tr>,
# ...
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 24<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Denver Round Robin </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/denver-round-robin-college/years/2019/divisions/college-open">College Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 23<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Virginia Showcase Series 2 </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/virginia-showcase-series-2-college/years/2019/divisions/college-open">College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/virginia-showcase-series-2-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 23<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Oak Creek Challenge </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/oak-creek-challenge-college/years/2019/divisions/college-open">College Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 23<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Commonwealth Cup </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/commonwealth-cup-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 23<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Chucktown Throwdown </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/chucktown-throwdown-college/years/2019/divisions/college-open">College Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 17<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Santa Clara Rage Presidents Day </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/santa-clara-rage-presidents-day-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 16<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Presidents Day Invite </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/presidents-day-invite-college/years/2019/divisions/college-open">College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/presidents-day-invite-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 16<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Music City Tune Up </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/music-city-tune-up-college/years/2019/divisions/college-open">College Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 16<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Luminous </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/luminous-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 16<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Jillz Jamboree </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/jillz-jamboree-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 16<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Easterns Qualifiers </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/easterns-qualifiers-college/years/2019/divisions/college-open">College Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 16<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Cherry Blossom Classic </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/cherry-blossom-classic-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 16<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Big D In Little D </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/big-d-in-little-d-college/years/2019/divisions/college-open">College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/big-d-in-little-d-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 9<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Virginia Showcase Series 2 9 </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/virginia-showcase-series-2-9-college/years/2019/divisions/college-open">College Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 9<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Ultimate Galentine S Celebration </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/ultimate-galentine-s-celebration-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 9<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Ugly Dome </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/ugly-dome-college/years/2019/divisions/college-open">College Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 9<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Stanford </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/stanford-college/years/2019/divisions/college-open">College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/stanford-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 9<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Queen City Tune Up </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/queen-city-tune-up-college/years/2019/divisions/college-open">College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/queen-city-tune-up-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 9<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Free State Classic </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/free-state-classic-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 9<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Antifreeze </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/antifreeze-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 8<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Florida Warm Up </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/florida-warm-up-college/years/2019/divisions/college-open">College Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 2<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Royal Crown Classic </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/royal-crown-classic-college/years/2019/divisions/college-open">College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/royal-crown-classic-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 2<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Presidents Day Qualifiers </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/presidents-day-qualifiers-college/years/2019/divisions/college-open">College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/presidents-day-qualifiers-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 2<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Mid Atlantic Warm Up </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/mid-atlantic-warm-up-college/years/2019/divisions/college-open">College Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Feb 2<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Hucking Shucking </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/hucking-shucking-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Jan 26<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Winta Binta Vinta Fest </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/winta-binta-vinta-fest-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Jan 26<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> New Year Fest </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/new-year-fest-college/years/2019/divisions/college-open">College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/new-year-fest-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Jan 26<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Flat Tail </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/flat-tail-college/years/2019/divisions/college-open">College Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Jan 26<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Clutch Classic </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/clutch-classic-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Jan 25<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Santa Barbara Invite </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/santa-barbara-invite-college/years/2019/divisions/college-open">College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/santa-barbara-invite-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Jan 25<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Carolina Kickoff </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/carolina-kickoff-college/years/2019/divisions/college-open">College Open</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Jan 19<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Florida Winter Classic </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/florida-winter-classic-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>,
#  <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Jan 4<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Red Eye </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/red-eye-club/years/2019/divisions/club-mixed">Club Mixed</a><!-- --><!-- --></td></tr>]

# %% [markdown]
# This is a lot better! Now we only have the table information instead of everything from the page. If we visit the page in a browser (link above), we can start to make sense of this: it looks like we have one `<td>` child tag for each table entry, so one for each date, tournament name/organizer, and all competition divisions. We don't need the dates, but we do need the tournament name/organizer and competition division cells.
#
# Let's look at one of the rows (one `tr` tag). In particular, we'll look at the children individually. To do this, we will call the `.children` attribute of the tag to get a generator containing all child tags. We'll convert this to a list to see what's going on:

# %%
tr_tag = soup.find_all('tr')[-4]
# We'll be using this particular tag for a running example.
pprint(tr_tag)
print()
pprint(list(tr_tag.children)) # again, .children returns a generator that we need to convert to a list to view.
# Out:
# <tr _ngcontent-jlt-c26="" class="ng-star-inserted"><td _ngcontent-jlt-c26=""> Jan 25<!-- --></td><td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Santa Barbara Invite </td><td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/santa-barbara-invite-college/years/2019/divisions/college-open">College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/santa-barbara-invite-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td></tr>
#
# [<td _ngcontent-jlt-c26=""> Jan 25<!-- --></td>,
#  <td _ngcontent-jlt-c26=""><span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span> Santa Barbara Invite </td>,
#  <td _ngcontent-jlt-c26=""><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/santa-barbara-invite-college/years/2019/divisions/college-open">College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/santa-barbara-invite-college/years/2019/divisions/college-womens">College Women's</a><!-- --><!-- --></td>]

# %% [markdown]
# To get the tournament type and links, we need to extract the bolded parts from the tags:
#
# `[<td _ngcontent-jua-c26=""> Jan 25<!-- --></td>,
#  <td _ngcontent-jua-c26=""><span _ngcontent-jua-c26="" class="tournament-type usau">`**`usau`**`</span> Santa Barbara Invite </td>,
#  <td _ngcontent-jua-c26=""><!-- --><a _ngcontent-jua-c26="" class="ng-star-inserted" `**`href="/tournaments/santa-barbara-invite-college/years/2019/divisions/college-open"`**`>College Open</a><!-- -->, <!-- --><!-- --><a _ngcontent-jua-c26="" class="ng-star-inserted" `**`href="/tournaments/santa-barbara-invite-college/years/2019/divisions/college-womens"`**`>College Women's</a><!-- --><!-- --></td>]`

# %% [markdown]
# Looking at which tags those are, we see that the tournament type tag has `class="tournament-type"`, and the link tags have the `href` attribute. We can do a search for those properties explicitly with BS.
#
# We'll eventually need to filter the links based on the tournament types, so we will find the types and the links separately.

# %%
tournament_type = tr_tag.find(class_="tournament-type") # searches for a particular class of tag (as opposed to attribute)
links = tr_tag.find_all(href=True) # searches for tags that have an href attribute

pprint(tournament_type)
print()
pprint(links)
# Out:
# <span _ngcontent-jlt-c26="" class="tournament-type usau">usau</span>
#
# [<a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/santa-barbara-invite-college/years/2019/divisions/college-open">College Open</a>,
#  <a _ngcontent-jlt-c26="" class="ng-star-inserted" href="/tournaments/santa-barbara-invite-college/years/2019/divisions/college-womens">College Women's</a>]

# %% [markdown]
# Great! The last thing we need to do is extract the information from the individual tags. For the tournament type, since that information is just the text content of the tag, we call `.text`. To get the `href` attribute from the tag, we call `href` as we would for a dictionary.

# %%
tournament_type = tr_tag.find(class_="tournament-type").text

links = [tag['href'] for tag in tr_tag.find_all(href=True)]

pprint(tournament_type)
pprint(links)
# Out:
# 'usau'
# ['/tournaments/santa-barbara-invite-college/years/2019/divisions/college-open',
#  '/tournaments/santa-barbara-invite-college/years/2019/divisions/college-womens']

# %% [markdown]
# We now know how to get the information we want out of a tag. We'll write a function to extract the information from an individual `tr` tag, including filtering for the division we want and adding the url prefix:

# %%
def extract_tournament_info(tr_tag, division='club-open'):
    """Extract the tournament type and ultiarchive link from a tag."""
    tournament_type = tr_tag.find(class_="tournament-type").text
    links = ["https://ultiarchive.com" + tag['href'] for tag in tr_tag.find_all(href=True) if division in tag['href']]
    # Makes links to each tournament as long as the link contains the right division.
    return tournament_type, links

# %% [markdown]
# Now we can iterate through each of the `tr` tags in the page:

# %%
def soup_to_list_of_tournaments(soup, division='club-open'):
    """Turn an ultiarchive soup into a list of all ultiarchive tournament links."""
    all_links = []
    for tr_tag in soup.find_all("tr"):
        tournament_type, links = extract_tournament_info(tr_tag, division)
        if tournament_type == "usau":
            all_links.extend(links)
    return all_links

# %%
club_open_tournaments = soup_to_list_of_tournaments(soup)
print(len(club_open_tournaments))
pprint(club_open_tournaments)
# Out:
# 72
# ['https://ultiarchive.com/tournaments/red-tide-ultimate-clambake-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/national-championships-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/southwest-regionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/southeast-regionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/south-central-regionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/northwest-regionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/northeast-regionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/north-central-regionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/mid-atlantic-regionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/great-lakes-regionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/nor-cal-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/west-plains-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/west-new-england-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/washington-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/upstate-new-york-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/texas-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/so-cal-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/rocky-mountain-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/ozarks-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/oregon-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/northwest-plains-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/north-carolina-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/metro-new-york-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/gulf-coast-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/founders-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/florida-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/east-plains-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/east-new-england-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/east-coast-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/central-plains-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/capital-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/big-sky-sectionals-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/tct-pro-championships-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/labor-day-recreational-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/the-incident-age-of-ultimatron-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/ski-town-classic-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/indy-invite-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/fcs-invite-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/tct-elite-select-challenge-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/mudbowl-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/hootie-on-the-hill-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/cooler-classic-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/nucci-s-cup-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/chesapeake-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/philly-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/heavyweights-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/cbr-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/us-open-championships-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/pb-j-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/angel-city-shootout-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/vacationland-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/the-royal-experience-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/terminus-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/stonewalled-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/the-br-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/tct-select-flight-invite-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/tct-pro-elite-challenge-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/swan-boat-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/riverside-classic-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/ow-my-knee-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/ok-corral-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/motown-throwdown-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/huntsville-huckfest-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/antlerlock-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/texas-2-finger-and-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/spirit-of-the-plains-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/scinny-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/fort-collins-summer-solstice-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/eugene-summer-solstice-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/boston-invite-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/san-diego-slammer-club/years/2019/divisions/club-open',
#  'https://ultiarchive.com/tournaments/atl-classic-club/years/2019/divisions/club-open']

# %% [markdown]
# If we go back in our browser and search for 'club open', we'll see that we get 75 matches, less three non-USAU tournaments. So we're getting what we want!
#
# If we want to start with just a year and get links out, we can write the following function:

# %%
def year_to_tournaments(year=2019, division='club-open'):
    """ Gets links to each ultiarchive tournament page for a given year"""
    url = fr"https://ultiarchive.com/years/{year}"
    # This is the general form for the ultiarchive pages
    soup = jspage_to_soup(url)
    links = soup_to_list_of_tournaments(soup, division='club-open')
    return links

# %% [markdown]
# Next we can look at actually reading tournaments.

# %% [markdown]
# ## 3 Reading tournaments

# %% [markdown]
# ### 3.1 Getting to the USAU website

# %% [markdown]
# To start, we need to find the USAU link at the top of the Ultiarchive tournament page. This is another JavaScript page so we'll use the `js_to_soup()` script defined above. Since the result we want is at the top of the page, we can set `scroll=False` to save some time.
#
# For this section, we'll use the 2019 Club Open National Championships as our example, since it's the largest tournament and has the most data to wrangle on the website. There are some other complications that come with smaller tournaments which we will address at the end. Let's take a look:
#
# *Note: Nationals is NOT a representative tournament, in part because it is are far better (and more consistently) documented than most other tournaments. This will be important later.

# %%
ultiarchive_link = club_open_tournaments[1]
print(ultiarchive_link)
ultiarchive_soup = jspage_to_soup(ultiarchive_link, scroll=False) # this will still take a couple seconds, but not 20
ultiarchive_soup.find_all(href=True)
# Out:
# https://ultiarchive.com/tournaments/national-championships-club/years/2019/divisions/club-open
# [<base href="/"/>,
#  <link href="favicon.png" rel="icon" type="image/x-icon"/>,
#  <link href="manifest.webmanifest" rel="manifest"/>,
#  <link href="https://firestore.googleapis.com" rel="preconnect"/>,
#  <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500" rel="stylesheet"/>,
#  <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet"/>,
#  <link href="https://cdnjs.cloudflare.com/ajax/libs/flag-icon-css/2.9.0/css/flag-icon.min.css" rel="stylesheet"/>,
#  <link href="styles.98a99bf1902d6c02d16b.css" rel="stylesheet"/>,
#  <a _ngcontent-fdf-c14="" href="/">Ultiarchive</a>,
#  <a _ngcontent-fdf-c23="" class="ng-star-inserted" href="https://play.usaultimate.org/events/USA-Ultimate-National-Championships-2019/schedule/Men/Club-Men/" rel="noopener" target="_blank"> USAU <i _ngcontent-fdf-c23="" class="material-icons">open_in_new</i></a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/sockeye-club-open/years/2019">Sockeye</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/dig-club-open/years/2019">DiG</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/socal-condors-club-open/years/2019">SoCal Condors</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/furious-george-club-open/years/2019">Furious George</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/pony-club-open/years/2019">PoNY</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/sub-zero-club-open/years/2019">Sub Zero</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/pittsburgh-temper-club-open/years/2019">Pittsburgh Temper</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/johnny-bravo-club-open/years/2019">Johnny Bravo</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/chicago-machine-club-open/years/2019">Chicago Machine</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/truck-stop-club-open/years/2019">Truck Stop</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/goat-club-open/years/2019">GOAT</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/chain-lightning-club-open/years/2019">Chain Lightning</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/ring-of-fire-club-open/years/2019">Ring of Fire</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/revolver-club-open/years/2019">Revolver</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/rhino-slam-club-open/years/2019">Rhino Slam!</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/doublewide-club-open/years/2019">Doublewide</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/sub-zero-club-open/years/2019">Sub Zero</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/goat-club-open/years/2019">GOAT</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/sockeye-club-open/years/2019">Sockeye</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/sub-zero-club-open/years/2019">Sub Zero</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/pittsburgh-temper-club-open/years/2019">Pittsburgh Temper</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/truck-stop-club-open/years/2019">Truck Stop</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/truck-stop-club-open/years/2019">Truck Stop</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/ring-of-fire-club-open/years/2019">Ring of Fire</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/sockeye-club-open/years/2019">Sockeye</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/ring-of-fire-club-open/years/2019">Ring of Fire</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/revolver-club-open/years/2019">Revolver</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/socal-condors-club-open/years/2019">SoCal Condors</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/chicago-machine-club-open/years/2019">Chicago Machine</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/revolver-club-open/years/2019">Revolver</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/rhino-slam-club-open/years/2019">Rhino Slam!</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/dig-club-open/years/2019">DiG</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/rhino-slam-club-open/years/2019">Rhino Slam!</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/pony-club-open/years/2019">PoNY</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/chicago-machine-club-open/years/2019">Chicago Machine</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/pony-club-open/years/2019">PoNY</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/sockeye-club-open/years/2019">Sockeye</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/chicago-machine-club-open/years/2019">Chicago Machine</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/furious-george-club-open/years/2019">Furious George</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/johnny-bravo-club-open/years/2019">Johnny Bravo</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/doublewide-club-open/years/2019">Doublewide</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/chain-lightning-club-open/years/2019">Chain Lightning</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/truck-stop-club-open/years/2019">Truck Stop</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/rhino-slam-club-open/years/2019">Rhino Slam!</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/revolver-club-open/years/2019">Revolver</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/sub-zero-club-open/years/2019">Sub Zero</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/truck-stop-club-open/years/2019">Truck Stop</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/revolver-club-open/years/2019">Revolver</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/dig-club-open/years/2019">DiG</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/doublewide-club-open/years/2019">Doublewide</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/chain-lightning-club-open/years/2019">Chain Lightning</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/socal-condors-club-open/years/2019">SoCal Condors</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/doublewide-club-open/years/2019">Doublewide</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/socal-condors-club-open/years/2019">SoCal Condors</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/rhino-slam-club-open/years/2019">Rhino Slam!</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/doublewide-club-open/years/2019">Doublewide</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/pittsburgh-temper-club-open/years/2019">Pittsburgh Temper</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/johnny-bravo-club-open/years/2019">Johnny Bravo</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/furious-george-club-open/years/2019">Furious George</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/goat-club-open/years/2019">GOAT</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/pittsburgh-temper-club-open/years/2019">Pittsburgh Temper</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/furious-george-club-open/years/2019">Furious George</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/furious-george-club-open/years/2019">Furious George</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/sub-zero-club-open/years/2019">Sub Zero</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/socal-condors-club-open/years/2019">SoCal Condors</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/pittsburgh-temper-club-open/years/2019">Pittsburgh Temper</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/dig-club-open/years/2019">DiG</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/chain-lightning-club-open/years/2019">Chain Lightning</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/johnny-bravo-club-open/years/2019">Johnny Bravo</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/goat-club-open/years/2019">GOAT</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/dig-club-open/years/2019">DiG</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/goat-club-open/years/2019">GOAT</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/chain-lightning-club-open/years/2019">Chain Lightning</a>,
#  <a _ngcontent-fdf-c29="" class="ng-star-inserted" href="/teams/johnny-bravo-club-open/years/2019">Johnny Bravo</a>]

# %% [markdown]
# If we look around 10 lines down we see the `play.usaultimate.org` link. If we want to get just this tag, we can search for matching attributes. We'll try the `rel="noopener` tag:

# %%
ultiarchive_soup.find(href=True, rel="noopener")
# Out:
# <a _ngcontent-fdf-c23="" class="ng-star-inserted" href="https://play.usaultimate.org/events/USA-Ultimate-National-Championships-2019/schedule/Men/Club-Men/" rel="noopener" target="_blank"> USAU <i _ngcontent-fdf-c23="" class="material-icons">open_in_new</i></a>

# %% [markdown]
# We can extract the link exactly as we did above.

# %%
def ulti_to_usau(url):
    """Converts an Ultiarchive tournament link to the corresponding USAU tournament link."""
    soup = jspage_to_soup(url, scroll=False)
    return soup.find(href=True, rel="noopener")["href"]

# %%
usau_link = ulti_to_usau(ultiarchive_link)
usau_link
# Out:
# 'https://play.usaultimate.org/events/USA-Ultimate-National-Championships-2019/schedule/Men/Club-Men/'

# %% [markdown]
# Finally, we'll update the function we wrote above to take us directly to the USAU links instead of the Ultiarchive links.

# %%
def year_to_tournaments(year=2019, division='club-open'):
    """ Gets links to each ultiarchive tournament page for a given year"""
    url = fr"https://ultiarchive.com/years/{year}"
    # This is the general form for the ultiarchive pages
    soup = jspage_to_soup(url)
    links = soup_to_list_of_tournaments(soup, division='club-open')
    print(links[:10])
    print("Found links!")
    usau_links = []
    for link in tqdm(links, position=0):
        print(link)
        usau_links.append(ulti_to_usau(link))
    return usau_links

# %%
### THIS WILL TAKE A LONG TIME!
usau_links = year_to_tournaments()
# Out:
# ['https://ultiarchive.com/tournaments/red-tide-ultimate-clambake-club/years/2019/divisions/club-open', 'https://ultiarchive.com/tournaments/national-championships-club/years/2019/divisions/club-open', 'https://ultiarchive.com/tournaments/southwest-regionals-club/years/2019/divisions/club-open', 'https://ultiarchive.com/tournaments/southeast-regionals-club/years/2019/divisions/club-open', 'https://ultiarchive.com/tournaments/south-central-regionals-club/years/2019/divisions/club-open', 'https://ultiarchive.com/tournaments/northwest-regionals-club/years/2019/divisions/club-open', 'https://ultiarchive.com/tournaments/northeast-regionals-club/years/2019/divisions/club-open', 'https://ultiarchive.com/tournaments/north-central-regionals-club/years/2019/divisions/club-open', 'https://ultiarchive.com/tournaments/mid-atlantic-regionals-club/years/2019/divisions/club-open', 'https://ultiarchive.com/tournaments/great-lakes-regionals-club/years/2019/divisions/club-open']
# Found links!
#   0%|          | 0/72 [00:00<?, ?it/s]
# https://ultiarchive.com/tournaments/red-tide-ultimate-clambake-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/national-championships-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/southwest-regionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/southeast-regionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/south-central-regionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/northwest-regionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/northeast-regionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/north-central-regionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/mid-atlantic-regionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/great-lakes-regionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/nor-cal-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/west-plains-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/west-new-england-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/washington-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/upstate-new-york-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/texas-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/so-cal-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/rocky-mountain-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/ozarks-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/oregon-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/northwest-plains-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/north-carolina-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/metro-new-york-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/gulf-coast-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/founders-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/florida-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/east-plains-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/east-new-england-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/east-coast-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/central-plains-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/capital-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/big-sky-sectionals-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/tct-pro-championships-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/labor-day-recreational-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/the-incident-age-of-ultimatron-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/ski-town-classic-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/indy-invite-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/fcs-invite-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/tct-elite-select-challenge-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/mudbowl-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/hootie-on-the-hill-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/cooler-classic-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/nucci-s-cup-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/chesapeake-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/philly-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/heavyweights-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/cbr-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/us-open-championships-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/pb-j-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/angel-city-shootout-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/vacationland-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/the-royal-experience-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/terminus-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/stonewalled-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/the-br-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/tct-select-flight-invite-club/years/2019/divisions/club-open
# https://ultiarchive.com/tournaments/tct-pro-elite-challenge-club/years/2019/divisions/club-open
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-43a50f46726b> in <module>
#       1 ### THIS WILL TAKE A LONG TIME!
# ----> 2 usau_links = year_to_tournaments()
#
# <ipython-input-37-15023f564dea> in year_to_tournaments(year, division)
#      10     for link in tqdm(links, position=0):
#      11         print(link)
# ---> 12         usau_links.append(ulti_to_usau(link))
#      13     return usau_links
#
# <ipython-input-35-12dc9c9eb761> in ulti_to_usau(url)
#       2     """Converts an Ultiarchive tournament link to the corresponding USAU tournament link."""
#       3     soup = jspage_to_soup(url, scroll=False)
# ----> 4     return soup.find(href=True, rel="noopener")["href"]
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# Now we've got what we need to move on to actually parsing the tournament.

# %% [markdown]
# ### 3.2 What data do we need?

# %% [markdown]
# The good news is that everything for the USAU website is hard-coded HTML, so it will be simpler to extract the data we need. The bad news is that the page structure is a lot more complicated! Take a look at https://play.usaultimate.org/events/USA-Ultimate-National-Championships-2019/schedule/Men/Club-Men/ (note: Men and Open are the same).
#
# We should also specify here what information we want to track. We also need to start thinking about how we want to structure things for Pandas (dataframe/spreadsheet creation), so we'll add column names here as well for reference. On a game-by-game basis, we want to get:
#
#     TN: Tournament name
#     GT: Game type (pool play or bracket play)
#     GST: Game subtype (pool number, 1st place bracket, crossover play)
#     BP: Bracket position (None for pool play, else quarterfinals / semifinals / etc.)
#     D: Date
#     T: Time
#     F: Field number
#     H: Home team
#     HSd: Home seed
#     HS: Home score
#     A: Away team
#     ASd: Away seed
#     AS: Away score
#
# This is all of the raw data that we can get-- we might want more columns (e.g. score differential), but in terms of creating a raw data set it is likely best to do that later.

# %% [markdown]
# ### 3.3 Getting the tournament name

# %% [markdown]
# With all that said, let's take a look at the source code! We will start by trying to figure out how to get a list of games out of the soup, as well as the name of the tournament.

# %%
usau_data = requests.get(usau_link)
usau_soup = BeautifulSoup(usau_data.text, 'html.parser')
usau_soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="html no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="html no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="html no-js lt-ie9"> <![endif]-->
# <!--[if IE 9 ]>        <html class="html no-js ie9"> <![endif]-->
# <!--[if gt IE 9]><!--> <html class="html no-js"> <!--<![endif]-->
# <head id="head"><meta content="SiteStartup Description" name="description"/><meta content="SiteStartup,Keywords" name="keywords"/><title>
# 	Competition Schedules and Results | Play USA Ultimate
# </title><meta charset="utf-8"/><meta content="width=device-width" name="viewport"/><meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/><link href="/cms/includes/style-new.v2.min.css" rel="stylesheet"/>
# <script src="/cms/includes/modernizr-1.7.min.js"></script>
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8.2/jquery.js"></script>
# <script>!window.jQuery && document.write(unescape('%3Cscript src="/cms/includes/jquery/jquery-1.8.2.js"%3E%3C/script%3E'))</script>
# <script src="/cms/includes/jquery-core-plugins.js"></script>
# <script type="text/javascript">
#   var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   (function() {
#     var gads = document.createElement('script');
#     gads.async = true;
#     gads.type = 'text/javascript';
#     var useSSL = 'https:' == document.location.protocol;
#     gads.src = (useSSL ? 'https:' : 'http:') +
#       '//securepubads.g.doubleclick.net/tag/js/gpt.js';
#     var node = document.getElementsByTagName('script')[0];
#     node.parentNode.insertBefore(gads, node);
#   })();
# </script>
# <script type="text/javascript">
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/96139156/EventPages_1column', [[970, 90], [728, 90]], 'div-gpt-ad-1449165694719-0').addService(googletag.pubads());
#     googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <script type="text/javascript">
#        /* <![CDATA[ */
#         var _gaq = _gaq || [];
#         _gaq.push(['_setAccount', 'UA-6731123-9']);
#         _gaq.push(['_trackPageview']);
#
#
#
#         (function() {
#             var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#             ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#             var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#         })();
#      /* ]]> */
#     </script>
# <script type="text/javascript">
#     var intrvl = 1000;
#     var sec = 60000;
#     var min = 3000 * sec;
#     //var min = 525600 * sec;
#     var warn = 3 * sec;
#     setInterval("checkSessionTime();", intrvl);
# 	function checkSessionTime() {
#         min -= intrvl;
#         var rm = parseInt(min / sec);
# 		var rs = parseInt((min - (rm * sec)) / 1000);
#
#         if (min <= 0) {
#             renewMemberSession(true);
#         } else {
#             var html = "Your session will expire in ";
#             if (rm > 3) {
#                 rm += 1;
#                 html += "<b>" + rm + "</b> minutes";
#             } else if (rm > 1) {
#                 html += "<b>" + rm + "</b> minutes and <b>" + rs + "</b> seconds";
#             } else if (rm == 1) {
#                 html += "<b>" + rm + "</b> minute and <b>" + rs + "</b> seconds";
#             } else {
#                 html += "<b>" + rs + "</b> seconds";
#             }
#
#             if (min % 10000 == 0) renewMemberSession(true); // every 10 seconds lets refresh the session, but don't reset the javascript timer
#         }
#     }
# 	function renewMemberSession(skipRenew) {
# 		$.getJSON("/ajax/ajax.aspx?F=ExtendSessionForMembers", function (o) {
# 			if (!o.success) {
#                 logout();
#             } else {
#                 if (!skipRenew) resetSession();
#             }
# 		});
#     }
#     //function logout() { $("#expires").html("<b>Your session has expired. Logging off...</b>"); try {$("#SessionTimeout").jqmShow().center();} catch(ex){} setTimeout("window.location = '/admin/logout.aspx';", 5000); }
#     function resetSession() { min = 3000 * sec; }
#     </script></head>
# <body class="body">
# <form action="/events/USA-Ultimate-National-Championships-2019/schedule/Men/Club-Men/" id="main" method="post">
# <div class="aspNetHidden">
# </div>
# <script src="/ScriptResource.axd?d=NJmAwtEo3Ipnlaxl6CMhvlId-D6C4GVKoJxVymjSOIU6Ws_RXyjgRct9nxZgtsCIos4D53TTX2WDvWuUUBDMHnOtQ_5r7tgVnVKTKFPRwkEkqTUYok_QnYjinVtVbF0t5Cdtt5QnIfsJET6jIinD3QzuAUg1&amp;t=ffffffff999c3159" type="text/javascript"></script>
# <div id="wrapper">
# <header id="main_header">
# <div id="logoArea">
# <span class="logo"><a href="http://www.usaultimate.org" target="_blank"><img alt="USA Ultimate" src="/cms/images/layout/logo.png"/></a></span>
# <span class="slogan"><img alt="Account Management" src="/cms/images/layout/slogan.png"/></span>
# <!-- Needs to be switched to account_header.png -->
# </div>
# <nav class="mainNav">
# <ul class="sf-menu clearfix">
# <li class="firstnavitemli" id="CT_Header_CC_TopNav_rptNav_ctl00_liItem">
# <a class="firstnavitema" href="https://usaultimate.org/about/" id="CT_Header_CC_TopNav_rptNav_ctl00_lnkLink1">About</a>
# <ul>
# <li>
# <a href="https://usaultimate.org/about/contacts/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl01_lnk" style="">Contact Us</a>
# <ul>
# <li>
# <a href="https://usaultimate.org/about/staff/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl01_lnkInner" style="">USA Ultimate Staff</a>
# </li>
# <li>
# <a href="https://usaultimate.org/about/contacts/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl02_lnkInner" style="">Youth Division</a>
# </li>
# <li>
# <a href="https://usaultimate.org/about/contacts/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl03_lnkInner" style="">College Division</a>
# </li>
# <li>
# <a href="https://usaultimate.org/about/contacts/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl04_lnkInner" style="">Club Division</a>
# </li>
# <li>
# <a href="https://usaultimate.org/about/contacts/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl05_lnkInner" style="">Masters Division</a>
# </li>
# <li>
# <a href="https://usaultimate.org/about/contacts/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl06_lnkInner" style="">Beach Division</a>
# </li>
# <li>
# <a href="https://usaultimate.org/affiliate-program/#CurrentAffiliates" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl07_lnkInner" style="">USA Ultimate Affiliates</a>
# </li>
# <li>
# <a href="https://usaultimate.org/state-based-organizations/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl08_lnkInner" style="">State-Based Organizations</a>
# </li>
# <li>
# <a href="https://usaultimate.org/about/board-of-directors/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl09_lnkInner" style="">Board of Directors</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://usaultimate.org/local/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl02_lnk" style="">Where to Play</a>
# </li>
# <li>
# <a href="https://usaultimate.org/discover-ultimate/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl03_lnk" style="">About Ultimate</a>
# <ul>
# <li>
# <a href="https://usaultimate.org/rules/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl03_rptSubSubNav_ctl01_lnkInner" style="">2020-21 Rules of Ultimate</a>
# </li>
# <li>
# <a href="https://usaultimate.org/spirit-of-the-game/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl03_rptSubSubNav_ctl02_lnkInner" style="">Spirit of the Game</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://usaultimate.org/about/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl04_lnk" style="">About USA Ultimate</a>
# <ul>
# <li>
# <a href="https://usaultimate.org/wp-content/uploads/2020/12/USA0125_AnnualReport2018_Final_LR.pdf" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl04_rptSubSubNav_ctl01_lnkInner" style="">Annual Report (2018)</a>
# </li>
# <li>
# <a href="https://usaultimate.org/about/volunteer/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl04_rptSubSubNav_ctl02_lnkInner" style="">Employment &amp; Volunteer Job Opportunities</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/about/history/hall_of_fame/default.aspx" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl05_lnk" style="">Hall of Fame</a>
# </li>
# <li>
# <a href="https://usaultimate.org/about/governance/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl06_lnk" style="">Governance</a>
# <ul>
# <li>
# <a href="https://usaultimate.org/wp-content/uploads/2020/03/USAUltimateBylaws_rev20171120.pdf" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl06_rptSubSubNav_ctl01_lnkInner" style="">Bylaws (2014)</a>
# </li>
# <li>
# <a href="https://usaultimate.org/about/suspensions/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl06_rptSubSubNav_ctl02_lnkInner" style="">Suspensions</a>
# </li>
# <li>
# <a href="https://usaultimate.org/strategic-plan/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl06_rptSubSubNav_ctl03_lnkInner" style="">Strategic Plan (2019-2021)</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://usaultimate.org/equity-diversity-inclusion/" id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_rptSubNav_ctl07_lnk" style="">Equity and Diversity</a>
# </li>
# </ul>
# <input id="CT_Header_CC_TopNav_rptNav_ctl00_ccSubNav_hdn" name="CT_Header$CC_TopNav$rptNav$ctl00$ccSubNav$hdn" type="hidden" value="6"/>
# </li>
# <li id="CT_Header_CC_TopNav_rptNav_ctl01_liItem">
# <a href="https://www.usaultimate.org/news/default.aspx" id="CT_Header_CC_TopNav_rptNav_ctl01_lnkLink1">News</a>
# <ul>
# <li>
# <a id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl01_lnk" style="">USA Ultimate Mobile App</a>
# <ul>
# <li>
# <a href="https://itunes.apple.com/us/app/usa-ultimate/id1032772331?mt=8" id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl01_lnkInner" style="">iOS</a>
# </li>
# <li>
# <a href="https://play.google.com/store/apps/details?id=org.usaultimate.usaultimate&amp;hl=en" id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl02_lnkInner" style="">Android</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://play.usaultimate.org/teams/events/rankings/" id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl02_lnk" style="">Rankings</a>
# <ul>
# <li>
# <a href="https://play.usaultimate.org/teams/events/team_rankings/?RankSet=College-Men" id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl01_lnkInner" style="">College Men's</a>
# </li>
# <li>
# <a href="https://play.usaultimate.org/teams/events/team_rankings/?RankSet=College-Women" id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl02_lnkInner" style="">College Women's</a>
# </li>
# <li>
# <a href="https://play.usaultimate.org/teams/events/team_rankings/?RankSet=Club-Men" id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl03_lnkInner" style="">TCT Men's</a>
# </li>
# <li>
# <a href="https://play.usaultimate.org/teams/events/team_rankings/?RankSet=Club-Mixed" id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl04_lnkInner" style="">TCT Mixed</a>
# </li>
# <li>
# <a href="https://play.usaultimate.org/teams/events/team_rankings/?RankSet=Club-Women" id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl05_lnkInner" style="">TCT Women's</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://usaultimate.org/news/topics/college/" id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl03_lnk" style="">College News</a>
# </li>
# <li>
# <a href="https://usaultimate.org/news/topics/club/" id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl04_lnk" style="">Triple Crown Tour News</a>
# </li>
# <li>
# <a href="https://usaultimate.org/news/topics/beach/" id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl05_lnk" style="">Beach News</a>
# </li>
# <li>
# <a href="https://usaultimate.org/news/topics/youth/" id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl06_lnk" style="">Youth News</a>
# </li>
# <li>
# <a href="https://usaultimate.org/news/topics/team-usa/" id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl07_lnk" style="">National Teams News</a>
# </li>
# <li>
# <a href="https://usaultimate.org/watch/" id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_rptSubNav_ctl08_lnk" style="">Videos</a>
# </li>
# </ul>
# <input id="CT_Header_CC_TopNav_rptNav_ctl01_ccSubNav_hdn" name="CT_Header$CC_TopNav$rptNav$ctl01$ccSubNav$hdn" type="hidden" value="25"/>
# </li>
# <li id="CT_Header_CC_TopNav_rptNav_ctl02_liItem">
# <a href="https://play.usaultimate.org/" id="CT_Header_CC_TopNav_rptNav_ctl02_lnkLink1">Events</a>
# <ul>
# <li>
# <a href="https://play.usaultimate.org/events/tournament/" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl01_lnk" style="">Tournament Calendar</a>
# <ul>
# <li>
# <a href="https://play.usaultimate.org/events/league/" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl01_lnkInner" style="">League Calendar</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://www.usaultimate.org/archives/" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_lnk" style="">Event Archives ('79-'19)</a>
# <ul>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2019.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl01_lnkInner" style="">2019</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2018.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl02_lnkInner" style="">2018</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2017.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl03_lnkInner" style="">2017</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2016.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl04_lnkInner" style="">2016</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2015.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl05_lnkInner" style="">2015</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2014.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl06_lnkInner" style="">2014</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2013.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl07_lnkInner" style="">2013</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2012.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl08_lnkInner" style="">2012</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2011.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl09_lnkInner" style="">2011</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2010.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl10_lnkInner" style="">2010</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2009.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl11_lnkInner" style="">2009</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2008.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl12_lnkInner" style="">2008</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2007.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl13_lnkInner" style="">2007</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2006.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl14_lnkInner" style="">2006</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2005.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl15_lnkInner" style="">2005</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2004.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl16_lnkInner" style="">2004</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2003.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl17_lnkInner" style="">2003</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2002.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl18_lnkInner" style="">2002</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2001.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl19_lnkInner" style="">2001</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/2000.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl20_lnkInner" style="">2000</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1999.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl21_lnkInner" style="">1999</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1998.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl22_lnkInner" style="">1998</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1997.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl23_lnkInner" style="">1997</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1996.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl24_lnkInner" style="">1996</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1995.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl25_lnkInner" style="">1995</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1994.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl26_lnkInner" style="">1994</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1993.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl27_lnkInner" style="">1993</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1992.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl28_lnkInner" style="">1992</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1991.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl29_lnkInner" style="">1991</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1990.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl30_lnkInner" style="">1990</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1989.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl31_lnkInner" style="">1989</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1988.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl32_lnkInner" style="">1988</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1987.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl33_lnkInner" style="">1987</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1986.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl34_lnkInner" style="">1986</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1985.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl35_lnkInner" style="">1985</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1984.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl36_lnkInner" style="">1984</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1983.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl37_lnkInner" style="">1983</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1982.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl38_lnkInner" style="">1982</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1981.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl39_lnkInner" style="">1981</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1980.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl40_lnkInner" style="">1980</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/archives/1979.aspx" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl41_lnkInner" style="">1979</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://play.usaultimate.org/events/2020-USA-Ultimate-Beach-Championships/" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl03_lnk" style="">Beach Championships</a>
# </li>
# <li>
# <a href="http://collegechampionships.usaultimate.org" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl04_lnk" style="">D-III College</a>
# </li>
# <li>
# <a href="http://collegechampionships.usaultimate.org" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl05_lnk" style="">D-I College</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/youth/default.aspx#season_hs" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl06_lnk" style="">H.S. States</a>
# </li>
# <li>
# <a href="http://usopen.usaultimate.org/" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl07_lnk" style="">YCC</a>
# </li>
# <li>
# <a href="http://usopen.usaultimate.org" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl08_lnk" style="">U.S. Open</a>
# </li>
# <li>
# <a href="https://play.usaultimate.org/events/TCT-Elite-Select-Challenge-2019/" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl09_lnk" style="">Elite-Select Challenge</a>
# </li>
# <li>
# <a href="https://play.usaultimate.org/events/TCT-Pro-Elite-Challenge-2019/" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl10_lnk" style="">Pro-Elite Challenge</a>
# </li>
# <li>
# <a href="https://play.usaultimate.org/events/TCT-Select-Flight-Invite-East-2019/" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl11_lnk" style="">Select Flight Invite - East</a>
# </li>
# <li>
# <a href="https://play.usaultimate.org/events/TCT-Select-Flight-Invite-West-2019/" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl12_lnk" style="">Select Flight Invite - West</a>
# </li>
# <li>
# <a href="https://play.usaultimate.org/events/TCT-Pro-Championships-2019/" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl13_lnk" style="">Pro Championships</a>
# </li>
# <li>
# <a href="http://tct.usaultimate.org/national-championships/" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl14_lnk" style="">National Championships</a>
# </li>
# <li>
# <a href="https://play.usaultimate.org/events/2019-USA-Ultimate-Masters-Championships/" id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_rptSubNav_ctl15_lnk" style="">Masters Championships</a>
# </li>
# </ul>
# <input id="CT_Header_CC_TopNav_rptNav_ctl02_ccSubNav_hdn" name="CT_Header$CC_TopNav$rptNav$ctl02$ccSubNav$hdn" type="hidden" value="144"/>
# </li>
# <li id="CT_Header_CC_TopNav_rptNav_ctl03_liItem">
# <a id="CT_Header_CC_TopNav_rptNav_ctl03_lnkLink1">Competition</a>
# <ul>
# <li>
# <a href="https://usaultimate.org/wp-content/uploads/2020/10/ReturnToPlayGuidance-June2020.pdf" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl01_lnk" style="">Return to Play Guidelines</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/youth/" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl02_lnk" style="">Youth Division</a>
# <ul>
# <li>
# <a href="https://usaultimate.org/youth/guidelines-and-registration/" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl01_lnkInner" style="">Youth Guidelines (2020)</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://www.usaultimate.org/college/" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl03_lnk" style="">College Division</a>
# <ul>
# <li>
# <a href="https://usaultimate.org/resources/college-eligibility-guidelines/" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl03_rptSubSubNav_ctl01_lnkInner" style="">College Eligibility</a>
# </li>
# <li>
# <a href="https://usaultimate.org/college/guidelines-and-registration/" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl03_rptSubSubNav_ctl02_lnkInner" style="">College Guidelines (2020)</a>
# </li>
# <li>
# <a href="https://usaultimate.org/wp-content/uploads/2020/12/College-Mixed-Guidelines.pdf" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl03_rptSubSubNav_ctl03_lnkInner" style="">College Mixed Guidelines (2019)</a>
# </li>
# <li>
# <a href="https://usaultimate.org/resources/?_resource_filters=college" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl03_rptSubSubNav_ctl04_lnkInner" style="">College Resources</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://www.usaultimate.org/club/" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl04_lnk" style="">Club Division (Triple Crown Tour)</a>
# <ul>
# <li>
# <a href="https://www.usaultimate.org/triplecrowntour/guidelines.aspx" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl04_rptSubSubNav_ctl01_lnkInner" style="">TCT Guidelines (2019)</a>
# </li>
# <li>
# <a href="https://play.usaultimate.org/events/2019-US-Open-Club-Championship/" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl04_rptSubSubNav_ctl02_lnkInner" style="">U.S. Open Club Championships</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://www.usaultimate.org/masters-ultimate/" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl05_lnk" style="">Masters Division</a>
# <ul>
# <li>
# <a href="https://www.usaultimate.org/masters_guidelines/" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl05_rptSubSubNav_ctl01_lnkInner" style="">Masters Guidelines (2019)</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://usaultimate.org/beach-ultimate/" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl06_lnk" style="">Beach Division</a>
# <ul>
# <li>
# <a href="https://www.usaultimate.org/beach/guidelines.aspx" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl06_rptSubSubNav_ctl01_lnkInner" style="">Beach Guidelines (2019)</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://usaultimate.org/team-usa/" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl07_lnk" style="">USA Ultimate National Teams</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/2020-national-skills-challenge/" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl08_lnk" style="">National Skills Challenge</a>
# <ul>
# <li>
# <a href="https://www.usaultimate.org/resources/national_skills_challenge_guidelines.aspx" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl08_rptSubSubNav_ctl01_lnkInner" style="">National Skills Challenge Guidelines (2020)</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/resources/skills_challenge.aspx" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl09_lnk" style="">Skills Challenge App Program</a>
# </li>
# <li>
# <a href="https://www.archive.usaultimate.org/resources/ultimate_disc_golf.aspx" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl10_lnk" style="">Ultimate Disc Golf Derby</a>
# <ul>
# <li>
# <a href="https://www.usaultimate.org/resources/ultimate_disc_golf_derby_guidelines.aspx" id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_rptSubNav_ctl10_rptSubSubNav_ctl01_lnkInner" style="">Ultimate Disc Golf Derby Guidelines (2020)</a>
# </li>
# </ul>
# </li>
# </ul>
# <input id="CT_Header_CC_TopNav_rptNav_ctl03_ccSubNav_hdn" name="CT_Header$CC_TopNav$rptNav$ctl03$ccSubNav$hdn" type="hidden" value="26"/>
# </li>
# <li id="CT_Header_CC_TopNav_rptNav_ctl04_liItem">
# <a href="https://usaultimate.org/programs/" id="CT_Header_CC_TopNav_rptNav_ctl04_lnkLink1">Programs</a>
# <ul>
# <li>
# <a href="https://usaultimate.org/affiliate-program/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl01_lnk" style="">Affiliates</a>
# <ul>
# <li>
# <a href="https://usaultimate.org/affiliate-program/#Benefits" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl01_lnkInner" style="">Benefits</a>
# </li>
# <li>
# <a href="https://usaultimate.org/affiliate-program/#Grants" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl02_lnkInner" style="">Grants</a>
# </li>
# <li>
# <a href="https://docs.google.com/forms/d/e/1FAIpQLSfEeecOBhzwri2jJNWtH-iGlUjQJ_y69L5I7RJK-Zs0rIg_UQ/viewform?c=0&amp;w=1" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl03_lnkInner" style="">Apply</a>
# </li>
# <li>
# <a href="https://usaultimate.org/affiliate-program/#FAQs" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl01_rptSubSubNav_ctl04_lnkInner" style="">FAQ</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://usaultimate.org/youth/camps-clinics/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl02_lnk" style="">Camps</a>
# </li>
# <li>
# <a href="https://usaultimate.org/wp-content/uploads/2020/11/Chaperone-Requirements.pdf" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl03_lnk" style="">Chaperones</a>
# <ul>
# <li>
# <a href="https://www.usaultimate.org/youth_requirements/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl03_rptSubSubNav_ctl01_lnkInner" style="">Youth Safety</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://usaultimate.org/coaches/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl04_lnk" style="">Coaching</a>
# <ul>
# <li>
# <a href="https://usaultimate.org/coaches/become-a-coach/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl04_rptSubSubNav_ctl01_lnkInner" style="">Coaching Development Program</a>
# </li>
# <li>
# <a href="https://usaultimate.org/athlete-safety/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl04_rptSubSubNav_ctl02_lnkInner" style="">Athlete Protection</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://usaultimate.org/sanctioning/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl05_lnk" style="">Event Sanctioning &amp; Insurance</a>
# <ul>
# <li>
# <a href="https://usaultimate.org/sanctioning/tournament-sanctioning/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl05_rptSubSubNav_ctl01_lnkInner" style="">Tournament Sanctioning</a>
# </li>
# <li>
# <a href="https://usaultimate.org/sanctioning/league-sanctioning/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl05_rptSubSubNav_ctl02_lnkInner" style="">League Sanctioning</a>
# </li>
# <li>
# <a href="https://usaultimate.org/sanctioning/development-event-sanctioning/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl05_rptSubSubNav_ctl03_lnkInner" style="">Practice Insurance</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="http://gum.usaultimate.org/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl06_lnk" style="">Girls' Ultimate Movement (GUM)</a>
# </li>
# <li>
# <a href="https://usaultimate.org/programs-services/learn-to-play" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl07_lnk" style="">Learn to Play</a>
# </li>
# <li>
# <a href="/events/2021_convention/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl08_lnk" style="">Coach &amp; Organizer Convention</a>
# </li>
# <li>
# <a href="https://usaultimate.org/programs-services/new-start" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl09_lnk" style="">New Start Grant Kits</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/resources/organizer_resources/default.aspx" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl10_lnk" style="">Organizer Resources</a>
# <ul>
# <li>
# <a href="https://www.usaultimate.org/resources/champ_events/default.aspx" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl10_rptSubSubNav_ctl01_lnkInner" style="">Bid to Host USA Ultimate Events</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/tdcp/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl10_rptSubSubNav_ctl02_lnkInner" style="">Tournament Director's Certification Program</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/resources/organizer_resources/ultimate_in_schools.aspx" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl10_rptSubSubNav_ctl03_lnkInner" style="">Youth &amp; Education Resources</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/resources/development/women/default.aspx" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl10_rptSubSubNav_ctl04_lnkInner" style="">Women's Development</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/resources/organizer_resources/college_development.aspx" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl10_rptSubSubNav_ctl05_lnkInner" style="">College Development</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/resources/organizer_resources/community_ultimate_development.aspx" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl10_rptSubSubNav_ctl06_lnkInner" style="">Ultimate in Your Community</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://www.usaultimate.org/resources/parent_resources.aspx" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl11_lnk" style="">Parent Resources</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/officiating/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl12_lnk" style="">Rules &amp; Officiating</a>
# <ul>
# <li>
# <a href="https://www.usaultimate.org/resources/officiating/rules/default.aspx" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl12_rptSubSubNav_ctl01_lnkInner" style="">Rules</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/resources/officiating/observers/default.aspx" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl12_rptSubSubNav_ctl02_lnkInner" style="">Observer Certification Program</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/resources/disc_standards.aspx" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl12_rptSubSubNav_ctl03_lnkInner" style="">Disc Standards</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://www.usaultimate.org/stateorgs/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl13_lnk" style="">State-Based Organizations</a>
# <ul>
# <li>
# <a href="https://www.usaultimate.org/stateorgreqs/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl13_rptSubSubNav_ctl01_lnkInner" style="">Benefits &amp; Requirements</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/stateorgfaq/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl13_rptSubSubNav_ctl02_lnkInner" style="">FAQ</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/contactstateorgs/" id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_rptSubNav_ctl13_rptSubSubNav_ctl03_lnkInner" style="">Contact State Orgs</a>
# </li>
# </ul>
# </li>
# </ul>
# <input id="CT_Header_CC_TopNav_rptNav_ctl04_ccSubNav_hdn" name="CT_Header$CC_TopNav$rptNav$ctl04$ccSubNav$hdn" type="hidden" value="27"/>
# </li>
# <li id="CT_Header_CC_TopNav_rptNav_ctl05_liItem">
# <a href="https://www.usaultimate.org/membership/default.aspx" id="CT_Header_CC_TopNav_rptNav_ctl05_lnkLink1">Membership</a>
# <ul>
# <li>
# <a href="https://www.usaultimate.org/membervalue/" id="CT_Header_CC_TopNav_rptNav_ctl05_ccSubNav_rptSubNav_ctl01_lnk" style="">Benefits &amp; Value</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/giftcertificate/" id="CT_Header_CC_TopNav_rptNav_ctl05_ccSubNav_rptSubNav_ctl02_lnk" style="">Gift Certificates</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/membershipimpact/" id="CT_Header_CC_TopNav_rptNav_ctl05_ccSubNav_rptSubNav_ctl03_lnk" style="">Impact of Our Members</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/memberships/" id="CT_Header_CC_TopNav_rptNav_ctl05_ccSubNav_rptSubNav_ctl04_lnk" style="">Membership Levels</a>
# <ul>
# <li>
# <a href="https://www.usaultimate.org/lifetimemembers/" id="CT_Header_CC_TopNav_rptNav_ctl05_ccSubNav_rptSubNav_ctl04_rptSubSubNav_ctl01_lnkInner" style="">Lifetime Members</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/yso/" id="CT_Header_CC_TopNav_rptNav_ctl05_ccSubNav_rptSubNav_ctl04_rptSubSubNav_ctl02_lnkInner" style="">Youth-Serving Organizations</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://www.usaultimate.org/membership/play_it_forward.aspx" id="CT_Header_CC_TopNav_rptNav_ctl05_ccSubNav_rptSubNav_ctl05_lnk" style="">Play It Forward</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/membership/default.aspx#Registration_Forms" id="CT_Header_CC_TopNav_rptNav_ctl05_ccSubNav_rptSubNav_ctl06_lnk" style="">Registration Forms: Waiver &amp; Medical Authorization</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/membership/signature_series.aspx" id="CT_Header_CC_TopNav_rptNav_ctl05_ccSubNav_rptSubNav_ctl07_lnk" style="">Signature Series Disc</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/membershiptrends/" id="CT_Header_CC_TopNav_rptNav_ctl05_ccSubNav_rptSubNav_ctl08_lnk" style="">Trends Over Time</a>
# </li>
# <li>
# <a href="/members/" id="CT_Header_CC_TopNav_rptNav_ctl05_ccSubNav_rptSubNav_ctl09_lnk" style="">Login</a>
# </li>
# </ul>
# <input id="CT_Header_CC_TopNav_rptNav_ctl05_ccSubNav_hdn" name="CT_Header$CC_TopNav$rptNav$ctl05$ccSubNav$hdn" type="hidden" value="28"/>
# </li>
# <li class="lastnavitemli" id="CT_Header_CC_TopNav_rptNav_ctl06_liItem">
# <a class="lastnavitema" href="http://shop.usaultimate.org/" id="CT_Header_CC_TopNav_rptNav_ctl06_lnkLink1">Shop</a>
# <ul>
# <li>
# <a href="https://www.usaultimate.org/merchandise/" id="CT_Header_CC_TopNav_rptNav_ctl06_ccSubNav_rptSubNav_ctl01_lnk" style="">USA Ultimate Discs, Kits &amp; Merchandise</a>
# </li>
# <li>
# <a href="http://usaultimate.teamfanshop.com/" id="CT_Header_CC_TopNav_rptNav_ctl06_ccSubNav_rptSubNav_ctl02_lnk" style="" target="_blank">Apparel &amp; Accessories</a>
# <ul>
# <li>
# <a href="http://usaultimate.teamfanshop.com/Mens" id="CT_Header_CC_TopNav_rptNav_ctl06_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl01_lnkInner" style="" target="_blank">Men</a>
# </li>
# <li>
# <a href="http://usaultimate.teamfanshop.com/Ladies" id="CT_Header_CC_TopNav_rptNav_ctl06_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl02_lnkInner" style="" target="_blank">Women</a>
# </li>
# <li>
# <a href="http://usaultimate.teamfanshop.com/Kids" id="CT_Header_CC_TopNav_rptNav_ctl06_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl03_lnkInner" style="" target="_blank">Kids</a>
# </li>
# <li>
# <a href="http://usaultimate.teamfanshop.com/T-Shirts" id="CT_Header_CC_TopNav_rptNav_ctl06_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl04_lnkInner" style="" target="_blank">T-Shirts</a>
# </li>
# <li>
# <a href="http://usaultimate.teamfanshop.com/Sweatshirts_And_Fleece" id="CT_Header_CC_TopNav_rptNav_ctl06_ccSubNav_rptSubNav_ctl02_rptSubSubNav_ctl05_lnkInner" style="" target="_blank">Sweats</a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://www.usaultimate.org/shop/additional_merchandise.aspx" id="CT_Header_CC_TopNav_rptNav_ctl06_ccSubNav_rptSubNav_ctl03_lnk" style="">Licensed Merchandise Suppliers</a>
# </li>
# <li>
# <a href="https://www.usaultimate.org/resources/disc_standards.aspx" id="CT_Header_CC_TopNav_rptNav_ctl06_ccSubNav_rptSubNav_ctl04_lnk" style="">Approved Disc Models</a>
# </li>
# </ul>
# <input id="CT_Header_CC_TopNav_rptNav_ctl06_ccSubNav_hdn" name="CT_Header$CC_TopNav$rptNav$ctl06$ccSubNav$hdn" type="hidden" value="29"/>
# </li>
# </ul>
# </nav>
# <div class="login_area">
# <div class="login_buttons" id="CT_LoginBar_0_login_buttons">
# <img src="/cms/images/icons/usoc_new_logo.png" width="160"/>
# <br/>
# <a class="btn" href="/members/login/">Member Account</a>
# </div>
# </div>
# </header>
# <div class="oneCol" id="container">
# <div class="column" id="main_col">
# <div class="headingBox">
# <div class="breadcrumbs_area">
# <div class="breadcrumbs">
# <a href="/events/tournament/">Home</a><span class="separator">&gt;</span><a href="/events/USA-Ultimate-National-Championships-2019/">USA Ultimate National Championships</a><span class="separator">&gt;</span>Schedules &amp; Standings
#     </div>
# </div>
# </div>
# <div class="alt_page_header has-link clearfix">
# <h1 class="title">Club - Men </h1>
# <a class="divCollapseBtn btn" href="javascript:void(0);"><img <="" a="" height="13px" src="/cms/images/buttons/btn_expand_collapse.png"/>
# <a class="btn back" href="/events/USA-Ultimate-National-Championships-2019/" id="CT_Main_0_lnkBack">Go back</a>
# </a></div>
# <div class="clear"></div>
# <script language="javascript" src="/cms/includes/jquery/bracket-calc.v2.min.js" type="text/javascript"></script>
# <script language="javascript" src="/cms/includes/jquery/hide-tied-gd.js" type="text/javascript"></script>
# <script language="javascript" type="text/javascript">
#     jQuery(function ($) {
# 	    $('.bracket_area').initBrackets();
# 	    $('#poolSlide').hideGoalDiff();
#
# 	    $('ul.tabs li a').click(function(){
# 	        var active_tab_index = $('ul.tabs li').index($(this).parent());
# 	        $.ajax({
# 	            type: 'GET',
# 	            url: '/Ajax.aspx',
# 	            data: {
# 	            F: 'SetTabSession',
# 	            idx: active_tab_index
# 	            },
#                 dataType: 'json',
#                 success: function (result) {
#                     if (result.success) {
#                         //console.log('Active tab session set');
#                     } else {
#                         console.log('Active tab session set Failed [' + result.error +']');
#                     }
#                 },
#                 error: function (result) {
#                     console.log('Active tab session set error');
#                 }
#             });
# 	    });
#
# 	    $('a.divCollapseBtn').click(function(){
# 	        $('h3.slide_trigger a').trigger('click');
# 	    });
#
# 	    checkStandings();
#     });
#
#     //expand all slides
#     $(window).load(function() {
#         $('h3.slide_trigger a').trigger('click');
#     });
#
# 	function checkStandings() {
# 	    $.ajax({
# 	        type: 'POST',
# 	        url: '/ajax/json.aspx',
# 	        data: {
# 	            f: 'STANDINGS_AMS',
# 	            Modified: '11/20/2019 9:58:11 PM',
# 	            event: 6925,
# 	            eventGroup: 9171
# 	            },
# 	        dataType: 'json',
# 	        success: function (result, textStatus) {
# 	            if (result.success) {
# 	                if(result.refresh){
# 	                    $( "#blackOverlay" ).show(100, function(){
# 	                        setTimeout(function() {
# 	                            window.location.href = window.location.href;
# 	                        }, 5000);
# 	                    });
# 	                }
# 	            } else {
# 	                console.log('Checking Standings: Error Received [' + result.error +']');
# 	            }
# 	        },
# 	        error: function (result, textStatus) {
# 	            console.log('Checking Standings: Error Received');
# 	            window.location.href = window.location.href;
# 	        }
# 	    });
# 	}
# </script>
# <style>
#     #blackOverlay {
#         background: url('/cms/images/admin/black-overlay-trans.png') repeat;
#         width: 100%;
#         height: 100%;
#         position: fixed;
#         z-index: 150;
#         display: none;
#         left: 5px;
#         top: 5px;
# 	}
# 	#blackOverlay div {
#         width: 110px;
#         margin: 0 auto;
#         margin-top: 300px;
#         opacity: 1;
# 	}
# </style>
# <div id="blackOverlay"><div style="width:250px;color:#fff;">Refreshing Standings and Event data...<br/><img src="/cms/images/admin/ajax-loader-trans.gif"/></div></div>
# <ul class="tabsLeft tabs">
# <li class="active" id="CT_Main_0_rptTabs_ctl01_liTab"><a href="#" rel="section_17160_1_9171">Pool Play</a></li>
# <li id="CT_Main_0_rptTabs_ctl02_liTab"><a href="#" rel="section_17165_3_9171">Championship Bracket</a></li>
# <li id="CT_Main_0_rptTabs_ctl03_liTab"><a href="#" rel="section_17166_3_9171">Consolation Brackets (2020 Pro Flight)</a></li>
# <li id="CT_Main_0_rptTabs_ctl04_liTab"><a href="#" rel="section_17167_3_9171">Consolation Brackets (2020 Elite Flight)</a></li>
# <li id="CT_Main_0_rptTabs_ctl05_liTab"><a href="#" rel="section_17168_2_9171">Crossover Round (4 Seeds from Pool Play)</a></li>
# </ul>
# <div class="slides">
# <section class="slide" id="poolSlide" style="display: block;">
# <div id="section_17160_1_9171">
# <section class="section page" data-sideitem="sideItem17160" data-type="pool">
# <div class="clearfix">
# <div class="pool">
# <h3 class="col_title">Pool A</h3>
# <table class="global_table">
# <tbody>
# <tr>
# <th scope="col">Team</th>
# <th scope="col">W - L</th>
# <th scope="col">Tie</th>
# </tr>
# <tr style="border: 1px solid #eee;">
# <td><a href="/events/teams/?EventTeamId=3VTuyn4K0uEO5wKkRo2a%2byPRB8glo6bXKUz9I12KYGs%3d">Sockeye (1)</a></td>
# <td class="WinLosePoints" style="padding-left: 3px; padding-right: 3px; text-align: left;">3 - 0</td>
# <td style="font-size: 10px"><span class="tieBreakerPoints"></span></td>
# </tr>
# <tr style="border: 1px solid #eee;">
# <td><a href="/events/teams/?EventTeamId=kWzNNcpBmG5PTUdHwKI61mo7M4GwqaWHx2NA3%2bibyrY%3d">DiG (8)</a></td>
# <td class="WinLosePoints" style="padding-left: 3px; padding-right: 3px; text-align: left;">2 - 1</td>
# <td style="font-size: 10px"><span class="tieBreakerPoints"></span></td>
# </tr>
# <tr style="border: 1px solid #eee;">
# <td><a href="/events/teams/?EventTeamId=gK%2f5oMD%2fNIeRr1Mmqxwyr0Hk%2bPGwvaz8bEsUR%2bbDOaQ%3d">SoCal Condors (12)</a></td>
# <td class="WinLosePoints" style="padding-left: 3px; padding-right: 3px; text-align: left;">1 - 2</td>
# <td style="font-size: 10px"><span class="tieBreakerPoints"></span></td>
# </tr>
# <tr style="border: 1px solid #eee;">
# <td><a href="/events/teams/?EventTeamId=vzpb%2fu1aVEX3V5noBFm2x9Tcdgjd6tO6afL2PKpKMvQ%3d">Furious George (13)</a></td>
# <td class="WinLosePoints" style="padding-left: 3px; padding-right: 3px; text-align: left;">0 - 3</td>
# <td style="font-size: 10px"><span class="tieBreakerPoints"></span></td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="pool">
# <h3 class="col_title">Pool B</h3>
# <table class="global_table">
# <tbody>
# <tr>
# <th scope="col">Team</th>
# <th scope="col">W - L</th>
# <th scope="col">Tie</th>
# </tr>
# <tr style="border: 1px solid #eee;">
# <td><a href="/events/teams/?EventTeamId=UfpFUO3irJYrH8eMmfnS3S8tpZA7tZvcjGAROSEEcek%3d">PoNY (2)</a></td>
# <td class="WinLosePoints" style="padding-left: 3px; padding-right: 3px; text-align: left;">3 - 0</td>
# <td style="font-size: 10px"><span class="tieBreakerPoints"></span></td>
# </tr>
# <tr style="border: 1px solid #eee;">
# <td><a href="/events/teams/?EventTeamId=w5L7kac2cXQfjUzRsOCsHfZfTH2LFRcVXVp6RrcmIys%3d">Sub Zero (7)</a></td>
# <td class="WinLosePoints" style="padding-left: 3px; padding-right: 3px; text-align: left;">2 - 1</td>
# <td style="font-size: 10px"><span class="tieBreakerPoints"></span></td>
# </tr>
# <tr style="border: 1px solid #eee;">
# <td><a href="/events/teams/?EventTeamId=E1CJS99bij09%2fCmvrNSbQwZcezL%2bn7XpwIhfy9vTkUg%3d">Pittsburgh Temper (11)</a></td>
# <td class="WinLosePoints" style="padding-left: 3px; padding-right: 3px; text-align: left;">1 - 2</td>
# <td style="font-size: 10px"><span class="tieBreakerPoints"></span></td>
# </tr>
# <tr style="border: 1px solid #eee;">
# <td><a href="/events/teams/?EventTeamId=cN19r9gPCZaAl5JlEOE%2ft6u%2bvI0YzW8mYCTvoinTzCs%3d">Johnny Bravo (14)</a></td>
# <td class="WinLosePoints" style="padding-left: 3px; padding-right: 3px; text-align: left;">0 - 3</td>
# <td style="font-size: 10px"><span class="tieBreakerPoints"></span></td>
# </tr>
# </tbody>
# </table>
# </div>
# <div class="pool">
# <h3 class="col_title">Pool C</h3>
# <table class="global_table">
# <tbody>
# <tr>
# <th scope="col">Team</th>
# <th scope="col">W - L</th>
# <th scope="col">Tie</th>
# </tr>
# <tr style="border: 1px solid #eee;">
# <td><a href="/events/teams/?EventTeamId=Qj3YTMLLCbPysvx90xMFfKt6d6iO99I83Pgyas4aJaU%3d">Chicago Machine (6)</a></td>
# <td class="WinLosePoints" style="padding-left: 3px; padding-right: 3px; text-align: left;">2 - 1</td>
# <td style="font-size: 10px"><span class="tieBreakerPoints">1-0,1</span><br/><span class="goalDifference" style="color: #68A7FF;">[+7]</span></td>
# </tr>
# <tr style="border: 1px solid #eee;">
# <td><a href="/events/teams/?EventTeamId=bdacM3R1Cl6lcXF7G3X45%2fqjW7NdtBqUNAGDqJmYqEA%3d">Truck Stop (3)</a></td>
# ...
# <span></span>
# <p><a href="/teams/events/match_report/?EventGameId=dnx5T4gTVtxFPfC9sQxhSpIioK0oGlYEo%2bVXEVax%2fdw%3d">G1</a></p>
# </div>
# </div>
# <div class="top_area loser">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-home">13</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-home"><a href="/events/teams/?EventTeamId=vzpb%2fu1aVEX3V5noBFm2x9Tcdgjd6tO6afL2PKpKMvQ%3d">Furious George (13)</a></span>
# </span>
# </div>
# <div class="btm_area winner">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-away">14</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-away"><a href="/events/teams/?EventTeamId=w5L7kac2cXQfjUzRsOCsHfZfTH2LFRcVXVp6RrcmIys%3d">Sub Zero (7)</a></span>
# </span>
# </div>
# <p class="location">18</p>
# <span class="game-status">Final</span>
# <span class="date">10/26/2019 9:00 AM</span>
# </div>
# </div>
# <div class="bracket_col">
# <h4 class="col_title">9th Place Semifinals</h4>
# <div class="bracket_game top_game has_next" data-index="1" data-relation="game241810" id="game241809">
# <div class="gameID_area">
# <div class="gameID">
# <span></span>
# <p><a href="/teams/events/match_report/?EventGameId=8ByeEG5lQLV%2bxUTU7fP26b4ZzOPDuiuHwQhSrScw96s%3d">G1</a></p>
# </div>
# </div>
# <div class="top_area loser">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-home">13</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-home"><a href="/events/teams/?EventTeamId=E1CJS99bij09%2fCmvrNSbQwZcezL%2bn7XpwIhfy9vTkUg%3d">Pittsburgh Temper (11)</a></span>
# </span>
# </div>
# <div class="btm_area winner">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-away">15</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-away"><a href="/events/teams/?EventTeamId=vzpb%2fu1aVEX3V5noBFm2x9Tcdgjd6tO6afL2PKpKMvQ%3d">Furious George (13)</a></span>
# </span>
# </div>
# <p class="location">14</p>
# <span class="game-status">Final</span>
# <span class="date">10/25/2019 4:15 PM</span>
# </div>
# </div>
# <div class="bracket_col">
# <h4 class="col_title">9th Place Quarterfinals</h4>
# <div class="bracket_game top_game has_next" data-index="1" data-relation="game241809" id="game241807">
# <div class="gameID_area">
# <div class="gameID">
# <span></span>
# <p><a href="/teams/events/match_report/?EventGameId=Aqh%2fVhsY%2bIpAKEj%2fNS2jjITnjfWTVt2x2RusbVQbkKk%3d">G1</a></p>
# </div>
# </div>
# <div class="top_area winner">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-home">15</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-home"><a href="/events/teams/?EventTeamId=E1CJS99bij09%2fCmvrNSbQwZcezL%2bn7XpwIhfy9vTkUg%3d">Pittsburgh Temper (11)</a></span>
# </span>
# </div>
# <div class="btm_area loser">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-away">12</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-away"><a href="/events/teams/?EventTeamId=cN19r9gPCZaAl5JlEOE%2ft6u%2bvI0YzW8mYCTvoinTzCs%3d">Johnny Bravo (14)</a></span>
# </span>
# </div>
# <p class="location">13</p>
# <span class="game-status">Final</span>
# <span class="date">10/25/2019 11:45 AM</span>
# </div>
# <div class="bracket_game btm_game has_next" data-index="2" data-relation="game241809" id="game241808">
# <div class="gameID_area">
# <div class="gameID">
# <span></span>
# <p><a href="/teams/events/match_report/?EventGameId=VESlucrnYZ8iT51Gd89iESc3d2%2fZaa5x8%2b17OOYcSnY%3d">G2</a></p>
# </div>
# </div>
# <div class="top_area winner">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-home">15</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-home"><a href="/events/teams/?EventTeamId=vzpb%2fu1aVEX3V5noBFm2x9Tcdgjd6tO6afL2PKpKMvQ%3d">Furious George (13)</a></span>
# </span>
# </div>
# <div class="btm_area loser">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-away">8</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-away"><a href="/events/teams/?EventTeamId=uwTGucLMGHis5UaEJftd7xaes6luFgnh2f9if66cCS8%3d">GOAT (10)</a></span>
# </span>
# </div>
# <p class="location">14</p>
# <span class="game-status">Final</span>
# <span class="date">10/25/2019 11:45 AM</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# </div>
# </section>
# <section class="slide" id="bracketSlide" style="display: none;">
# <div id="section_17167_3_9171">
# <section class="section page" data-sideitem="siteItem17167" data-type="cluster">
# <div class="mod_slide alt_slide">
# <h3 class="slide_trigger">
# <a href="#">11th Place Bracket</a>
# </h3>
# <div class="mod_slide_contents">
# <div class="bracket_wrpr">
# <div class="bracket_area clearfix">
# <div class="bracket_col">
# <h4 class="col_title">11th Place</h4>
# <div class="bracket_game top_game" data-index="1" data-relation="" id="game241811">
# <div class="gameID_area">
# <div class="gameID">
# <span></span>
# <p><a href="/teams/events/match_report/?EventGameId=cYldVkggThHv3MLa5Z1hA1Z7o%2bZWwzG6i8q02si4WkA%3d">G1</a></p>
# </div>
# </div>
# <div class="top_area winner">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-home">15</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-home"><a href="/events/teams/?EventTeamId=gK%2f5oMD%2fNIeRr1Mmqxwyr0Hk%2bPGwvaz8bEsUR%2bbDOaQ%3d">SoCal Condors (12)</a></span>
# </span>
# </div>
# <div class="btm_area loser">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-away">13</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-away"><a href="/events/teams/?EventTeamId=E1CJS99bij09%2fCmvrNSbQwZcezL%2bn7XpwIhfy9vTkUg%3d">Pittsburgh Temper (11)</a></span>
# </span>
# </div>
# <p class="location">17</p>
# <span class="game-status">Final</span>
# <span class="date">10/26/2019 9:00 AM</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="section page" data-sideitem="siteItem17167" data-type="cluster">
# <div class="mod_slide alt_slide">
# <h3 class="slide_trigger">
# <a href="#">13th Place Bracket</a>
# </h3>
# <div class="mod_slide_contents">
# <div class="bracket_wrpr">
# <div class="bracket_area clearfix">
# <div class="bracket_col">
# <h4 class="col_title">13th Place Finals</h4>
# <div class="bracket_game top_game" data-index="1" data-relation="" id="game241814">
# <div class="gameID_area">
# <div class="gameID">
# <span></span>
# <p><a href="/teams/events/match_report/?EventGameId=Mvzd0Vc0vcefuk8k2gggdRVcPfRTN6DUWhRSaoM%2bxWk%3d">G1</a></p>
# </div>
# </div>
# <div class="top_area loser">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-home">12</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-home"><a href="/events/teams/?EventTeamId=kWzNNcpBmG5PTUdHwKI61mo7M4GwqaWHx2NA3%2bibyrY%3d">DiG (8)</a></span>
# </span>
# </div>
# <div class="btm_area winner">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-away">15</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-away"><a href="/events/teams/?EventTeamId=uwTGucLMGHis5UaEJftd7xaes6luFgnh2f9if66cCS8%3d">GOAT (10)</a></span>
# </span>
# </div>
# <p class="location">14</p>
# <span class="game-status">Final</span>
# <span class="date">10/26/2019 9:00 AM</span>
# </div>
# </div>
# <div class="bracket_col">
# <h4 class="col_title">13th Place Semifinals</h4>
# <div class="bracket_game top_game has_next" data-index="1" data-relation="game241814" id="game241812">
# <div class="gameID_area">
# <div class="gameID">
# <span></span>
# <p><a href="/teams/events/match_report/?EventGameId=iiW2hfKTuK8Ce7MsNpZm13SDo6rzc%2bJQLBSasr0y%2fIw%3d">G1</a></p>
# </div>
# </div>
# <div class="top_area winner">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-home">15</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-home"><a href="/events/teams/?EventTeamId=kWzNNcpBmG5PTUdHwKI61mo7M4GwqaWHx2NA3%2bibyrY%3d">DiG (8)</a></span>
# </span>
# </div>
# <div class="btm_area loser">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-away">14</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-away"><a href="/events/teams/?EventTeamId=3Kg491Qzxe0%2bNqvF69SWwH0vxUI4yQV2gUjLZA3Ie%2bY%3d">Chain Lightning (15)</a></span>
# </span>
# </div>
# <p class="location">13</p>
# <span class="game-status">Final</span>
# <span class="date">10/25/2019 2:00 PM</span>
# </div>
# <div class="bracket_game btm_game has_next" data-index="2" data-relation="game241814" id="game241813">
# <div class="gameID_area">
# <div class="gameID">
# <span></span>
# <p><a href="/teams/events/match_report/?EventGameId=Uv%2fkrv%2bFqoRzKiqC8h8rQYl8yW91zx9xdsJhfTG5dLk%3d">G2</a></p>
# </div>
# </div>
# <div class="top_area loser">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-home">8</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-home"><a href="/events/teams/?EventTeamId=cN19r9gPCZaAl5JlEOE%2ft6u%2bvI0YzW8mYCTvoinTzCs%3d">Johnny Bravo (14)</a></span>
# </span>
# </div>
# <div class="btm_area winner">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-away">15</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-away"><a href="/events/teams/?EventTeamId=uwTGucLMGHis5UaEJftd7xaes6luFgnh2f9if66cCS8%3d">GOAT (10)</a></span>
# </span>
# </div>
# <p class="location">14</p>
# <span class="game-status">Final</span>
# <span class="date">10/25/2019 2:00 PM</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <section class="section page" data-sideitem="siteItem17167" data-type="cluster">
# <div class="mod_slide alt_slide">
# <h3 class="slide_trigger">
# <a href="#">15th Place Bracket</a>
# </h3>
# <div class="mod_slide_contents">
# <div class="bracket_wrpr">
# <div class="bracket_area clearfix">
# <div class="bracket_col">
# <h4 class="col_title">15th Place</h4>
# <div class="bracket_game top_game" data-index="1" data-relation="" id="game241815">
# <div class="gameID_area">
# <div class="gameID">
# <span></span>
# <p><a href="/teams/events/match_report/?EventGameId=Yi9Il8jY%2f1q1o9XlSkwEycKwDNJ7FFtAmRA4%2fwWN%2b0k%3d">G1</a></p>
# </div>
# </div>
# <div class="top_area loser">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-home">11</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-home"><a href="/events/teams/?EventTeamId=3Kg491Qzxe0%2bNqvF69SWwH0vxUI4yQV2gUjLZA3Ie%2bY%3d">Chain Lightning (15)</a></span>
# </span>
# </div>
# <div class="btm_area winner">
# <span class="isScore">
# <span class="score adjust-data" data-type="game-score-away">14</span>
# </span>
# <span class="isName">
# <span class="team adjust-data" data-type="game-team-away"><a href="/events/teams/?EventTeamId=cN19r9gPCZaAl5JlEOE%2ft6u%2bvI0YzW8mYCTvoinTzCs%3d">Johnny Bravo (14)</a></span>
# </span>
# </div>
# <p class="location">18</p>
# <span class="game-status">Final</span>
# <span class="date">10/26/2019 11:15 AM</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# </div>
# </section>
# <section class="slide" id="clusterSlide" style="display: none;">
# <div id="section_17168_2_9171">
# <section class="section page" data-sideitem="siteItem17168" data-type="cluster">
# <table class="global_table scores_table">
# <thead>
# <tr>
# <th colspan="8">Crossover Round (4 Seeds from Pool Play)</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <th scope="col">Date</th>
# <th scope="col">Time</th>
# <th scope="col">Field</th>
# <th scope="col">Team 1</th>
# <th scope="col">Team 2</th>
# <th scope="col">Score</th>
# <th scope="col">Status</th>
# <th scope="col">Options</th>
# </tr>
# <tr data-game="241816">
# <td>
# <span class="adjust-data" data-type="game-date">Fri 10/25</span>
# </td>
# <td>
# <span class="adjust-data" data-type="game-time">9:00 AM</span>
# </td>
# <td>
# <span class="adjust-data" data-type"game-field"="">13</span>
# </td>
# <td>
# <span class="adjust-data" data-type="game-team-home">
# <a href="/events/teams/?EventTeamId=XYy%2bIawK1CS0xrYcBjYa7dNBAxXn8M9BbXo2ssXLqh8%3d">Doublewide (9)</a>
# </span>
# </td>
# <td>
# <span class="adjust-data" data-type="game-team-away">
# <a href="/events/teams/?EventTeamId=3Kg491Qzxe0%2bNqvF69SWwH0vxUI4yQV2gUjLZA3Ie%2bY%3d">Chain Lightning (15)</a>
# </span>
# </td>
# <td>
# <span class="isScore">
# <span class="adjust-data" data-type="game-score-home">10</span>
# </span>
# 							 -
# 							<span class="isScore">
# <span class="adjust-data" data-type="game-score-away">15</span>
# </span>
# </td>
# <td>
# <span class="adjust-data" data-type="game-status">Final</span>
# </td>
# <td class="options">
# <a class="options editGame editCluster" href="/teams/events/match_report/?EventGameId=L7t8Tas0wOU55Gqmp%2fgpfSTPIhhQfLylvQls7abWgZE%3d">
# <span>Match Report</span>
# </a>
# </td>
# </tr>
# <tr class="alt" data-game="241817">
# <td>
# <span class="adjust-data" data-type="game-date">Fri 10/25</span>
# </td>
# <td>
# <span class="adjust-data" data-type="game-time">9:00 AM</span>
# </td>
# <td>
# <span class="adjust-data" data-type"game-field"="">14</span>
# </td>
# <td>
# <span class="adjust-data" data-type="game-team-home">
# <a href="/events/teams/?EventTeamId=vzpb%2fu1aVEX3V5noBFm2x9Tcdgjd6tO6afL2PKpKMvQ%3d">Furious George (13)</a>
# </span>
# </td>
# <td>
# <span class="adjust-data" data-type="game-team-away">
# <a href="/events/teams/?EventTeamId=cN19r9gPCZaAl5JlEOE%2ft6u%2bvI0YzW8mYCTvoinTzCs%3d">Johnny Bravo (14)</a>
# </span>
# </td>
# <td>
# <span class="isScore">
# <span class="adjust-data" data-type="game-score-home">11</span>
# </span>
# 							 -
# 							<span class="isScore">
# <span class="adjust-data" data-type="game-score-away">15</span>
# </span>
# </td>
# <td>
# <span class="adjust-data" data-type="game-status">Final</span>
# </td>
# <td class="options">
# <a class="options editGame editCluster" href="/teams/events/match_report/?EventGameId=pRbQQ99TrS9bWZYMBOBTwlePZuZZ6o58OcvfRlOME68%3d">
# <span>Match Report</span>
# </a>
# </td>
# </tr>
# </tbody>
# </table>
# </section>
# </div>
# </section>
# </div>
# <center><br/><hr/><br/><!-- /96139156/EventPages_1column -->
# <div id="div-gpt-ad-1449165694719-0">
# <script type="text/javascript">
# if (document.location.pathname !== '/admin/content/pages/editor.aspx') {
# googletag.cmd.push(function() { googletag.display('div-gpt-ad-1449165694719-0'); });
# }
# </script>
# </div></center><br/>
# </div>
# </div>
# </div>
# <div id="footer">
# <div class="footer">
# <div class="footer_info clearfix">
# 	© 2021 usaultimate.org All Rights Reserved.
# 	<ul class="footer_links clearfix">
# <li><a href="http://www.usaultimate.org/privacy_policy.aspx">Privacy Policy</a></li>
# <li>|</li>
# <li><a href="http://www.usaultimate.org/site_map.aspx">Site Map</a></li>
# <li>|</li>
# <li><a href="http://www.usaultimate.org/about/contacts/">Contact Us</a></li>
# </ul>
# </div>
# <div class="vcard">
# <a class="fn org url" href="http://www.usaultimate.org">USA Ultimate</a>
# <div class="adr">
# <div><span class="street-address">5825 Delmonico Dr</span> • <span class="extended-address">Suite 370</span></div>
# 		<span class="locality">Colorado Springs</span>,
# 		<abbr class="region" title="Colorado">CO</abbr>
# <span class="postal-code">80919</span>
# <div class="country-name">USA</div>
# </div>
# <div class="tel">719.219.8322 <span class="type">Work</span></div>
# </div>
# </div>
# </div>
# <script src="/cms/includes/jquery/jquery-functions.js"></script>
# <script src="/cms/includes/functionsC.js" type="text/javascript"></script>
# <div class="aspNetHidden">
# <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="3989C74E"/>
# <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="+sJUUkW3OoVrDK+rhG5QBq7okI/R6BHpmm3R8INiGgxcOvAN21DHRaLEWfGs28B9KyHZHjMsTBGkloZARgdR/Hyhm1STZ4IhS33/ARJv5zzb3m3yT3JD1HXyFspMb5g0HNhfhDEh7PsvxWeUCsaY2um/Kcok8CD23WcU8kd+eBB8yzfMmNtoPpCZrN8ihfByIkoFoBMsKwjI0cTlo9e0LOqv2FoyiUrYstQitqhx/YFMIFLA"/>
# </div><input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="..."/></form>
# </body>
# </html>

# %% [markdown]
# That is, as always, a lot. To start with, let's just try to find the name of the tournament. If we visit the webpage again, the tournament name is found in the small navigation bar: `Home > USA Ultimate National Championships > Schedules & Standings`. Checking the source code (in Chrome, we can use Inspect Element for this), we see that we need:
#
# `v class="column" id="main_col"> <div class="headingBox"> <div class="breadcrumbs_area"> <div class="breadcrumbs"> <a href="/events/tournament/">Home</a><span class="separator">&gt;</span>`**`<a href="/events/USA-Ultimate-National-Championships-2019/">USA Ultimate National Championships</a><span class="separator">`**`&gt;</span>Schedules &amp; Standings    </div></div></di...`

# %% [markdown]
# So we can start by looking for the `breadcrumbs` class:

# %%
usau_soup.find(class_="breadcrumbs")
# Out:
# <div class="breadcrumbs">
# <a href="/events/tournament/">Home</a><span class="separator">&gt;</span><a href="/events/USA-Ultimate-National-Championships-2019/">USA Ultimate National Championships</a><span class="separator">&gt;</span>Schedules &amp; Standings
#     </div>

# %% [markdown]
# We'll always have a "Home" entry before the tournament name, so we can look at the children of this tag and pick the correct list item, then get the text from there.

# %%
pprint(list(usau_soup.find(class_="breadcrumbs").children))

print()

tournament_name = list(usau_soup.find(class_="breadcrumbs").children)[3].text
print(tournament_name)
# Out:
# ['\n',
#  <a href="/events/tournament/">Home</a>,
#  <span class="separator">&gt;</span>,
#  <a href="/events/USA-Ultimate-National-Championships-2019/">USA Ultimate National Championships</a>,
#  <span class="separator">&gt;</span>,
#  'Schedules & Standings\r\n    ']
#
# USA Ultimate National Championships

# %% [markdown]
# So that's one step down. We'll make this into a function for clarity.

# %%
def get_tournament_name(soup):
    """Get the name of a tournament from a soup."""
    return list(soup.find(class_="breadcrumbs").children)[3].text

# %% [markdown]
# ### 3.4 How do we actually get the game types we want?

# %% [markdown]
# This is the part where things get difficult. To understand what is going on, we first need to have a good understanding of how we *want* the data to look. For the USAU National Championships, we have the following game types, subtypes, and bracket positions:

# %% [markdown]
# | Game type | Game Subtype | Bracket Position |
# | --- | --- | --- |
# | Pool | | |
# | | Pool A | |
# | | Pool B | |
# | | Pool C | |
# | | Pool D | |
# | Bracket | | |
# | | 1st Place Bracket | |
# | | | Pre-Quarterfinals |
# | | | Quarterfinals |
# | | | Semifinals |
# | | | Finals |
# | | 5th Place Bracket | |
# | | | 5th Place Semifinals |
# | | | 5th Place Finals |
# | | 7th Place Bracket (Pro-Flight Play-In (A)| |
# | | | 9th Place Quarterfinals |
# | | | 9th Place Semifinals |
# | | | Pro Flight Play-In / 7th Place (tie) |
# | | 7th Place Bracket - Pro Flight Play-In (B) | |
# | | | 9th Place Quarterfinals |
# | | | 9th Place Semifinals |
# | | | Pro Flight Play-In / 7th Place (tie) |
# | | 11th Place Bracket | |
# | | | 11th Place |
# | | 13th Place Bracket | |
# | | | 13th Place Semifinals |
# | | | 13th Place Finals |
# | | 15th Place Bracket | |
# | | | 15th Place |
# | | Crossover Round (4 Seeds From Pool Play) |

# %% [markdown]
# In an ideal world, we would be able to scrape this data as follows:
#
#     1. Get containers for pool and bracket play.
#     2. For each container, get containers for the subtype containers (Pool A/B/C/D, 1st place bracket, etc.).
#     3. For each subtype container, get containers for each bracket position (or return same container if pool).
#     4. From each bracket position container, get each game.
#
# Unfortunately, there are a few problems:
#
# - We don't actually have separate containers for pool and bracket play, rather, the tabs we see (Pool Play, Championship Bracket, Consolation Bracket, etc.) are the containers that contain the subtypes we want.
# - There are different data structures for pool play games as opposed to bracket games, so we have to handle each of these cases differently.
#     - One important problem is that the crossover round is formatted as pool play, so we can't use whatever label we generate for the game type to tell us which kind of game to expect.
#
#     In other words, we might otherwise want to find the game type first and use that as part of the game reading process to figure out whether to expect the pool formatting or the bracket formatting, but the crossover round will mean that that approach won't work.
#
# - **THIS STRUCTURE DOESN'T WORK FOR OTHER TOURNAMENTS!** Check out:
#
#     [Great Lakes Men's Club Regional Championship](https://play.usaultimate.org/events/Great-Lakes-Mens-Club-Regional-Championship-2021/schedule/Men/Club-Men/)
#
#     [Southeast Club Club Men's Regional Championship](https://play.usaultimate.org/events/Southeast-Club-Mens-Regional-Championship-2021/schedule/Men/Club-Men/)
#
#     There are a lot of different formats here, and we need to make sure we handle things appropriately. In the latter example, we would probably want to treat the "Consolations 13th-15th pool" as bracket play even though it is labeled as pool play and has pool play game formatting, since it is being played for final placements.
#
#
#
#
# Overall, we will try to handle things as follows:
#
#     1. Get all SUBTYPE containers (these are more convenient to find)
#     2. For each subtype container, assign a game type of either *Pool* or *Bracket* based on the name of the container (e.g. if the name contains the word "pool" and does not contain a placement ordinal ("9th", for instance), call it a pool play container.
#     3. For each subtype container, get the bracket position if possible. If none exists, just use the subtype container (for pool play)
#     4. For each bracket position container, read the games within. Determine which kind of data structure to read based on  the contents of the container.
#
# Our hope is that this approach will be the most resistant to different tournament structures and the inconsistent labeling in the data.

# %% [markdown]
# ## 4.4 Game types, subtypes, and bracket positions

# %% [markdown]
# We will try to use the `class="section page"` tag to find the subtype containers. We can find the subtype containers that we want as below:

# %%
for subtype_container in usau_soup.find_all(class_="global_table scores_table"): 
    # "Things that are stored as pool play, but may or may not ACTUALLY be pool play:"
    name = subtype_container.find("th", colspan="8").text
    print(name)

for subtype_container in usau_soup.find_all(class_="mod_slide alt_slide"):
    # "Things that are stored as bracket play, but may or may not ACTUALLY be bracket play:"
    name = subtype_container.find(href="#").text
    print(name)
# Out:
# Pool A Schedule & Scores
# Pool B Schedule & Scores
# Pool C Schedule & Scores
# Pool D Schedule & Scores
# Crossover Round (4 Seeds from Pool Play)
# 1st Place Bracket
# 5th Place Bracket
# 7th Place Bracket - Pro Flight Play-In (A)
# 7th Place Bracket - Pro Flight Play-In (B)
# 11th Place Bracket
# 13th Place Bracket
# 15th Place Bracket

# %% [markdown]
# Let's wrap this into a function:

# %%
def get_subtype_container_lists(soup):
    """Gets list of all subtype containers from a tournament soup."""
    containers = []
    
    for subtype_container in soup.find_all(class_="global_table scores_table"): 
    # "Things that are stored as pool play, but may or may not ACTUALLY be pool play:"
        name = subtype_container.find("th", colspan="8").text
        containers.append([subtype_container, name])

    for subtype_container in soup.find_all(class_="mod_slide alt_slide"):
    # "Things that are stored as bracket play, but may or may not ACTUALLY be bracket play:"
        name = subtype_container.find(href="#").text
        containers.append([subtype_container, name])
    
    return containers

pprint([container[1] for container in get_subtype_container_lists(usau_soup)])
subtype_names = [container[1] for container in get_subtype_container_lists(usau_soup)]
# Out:
# ['Pool A Schedule & Scores',
#  'Pool B Schedule & Scores',
#  'Pool C Schedule & Scores',
#  'Pool D Schedule & Scores',
#  'Crossover Round (4 Seeds from Pool Play)',
#  '1st Place Bracket',
#  '5th Place Bracket',
#  '7th Place Bracket - Pro Flight Play-In (A)',
#  '7th Place Bracket - Pro Flight Play-In (B)',
#  '11th Place Bracket',
#  '13th Place Bracket',
#  '15th Place Bracket']

# %% [markdown]
# Now we need to take these containers and figure out whether it is pool or bracket play. We will use the following conditions for pool play (and say everything else is bracket):
#
# *A container name represents pool play if...*
# - It does NOT contain the word "crossover"
# - It does NOT contain an ordinal ("1st", "2nd", "3rd", etc.)
# - It DOES contain the word "pool"
#
# We can determine this from a string as follows. We'll immediately write this as a function.

# %%
def subtype_name_to_type(subtype_name):
    """Determines whether a given subtype container name corresponds to pool or bracket play."""
    if not any([keyword in subtype_name.lower() for keyword in ["st", "nd", "rd", "th", "crossover"]])\
        and "pool" in subtype_name.lower():
        return "Pool"
    else:
        return "Bracket"

def subtype_lists_to_type_lists(subtype_lists):
    """Adds game types to list of subtype containers."""
    for lst in subtype_lists:
        lst.insert(1, subtype_name_to_type(lst[1]))
    return subtype_lists

def get_type_container_lists(soup):
    """Gets list of subtype containers with types from a tournament soup."""
    subtype_lists = get_subtype_container_lists(soup)
    return subtype_lists_to_type_lists(subtype_lists)

pprint([container[1:] for container in get_type_container_lists(usau_soup)])
type_subtype_lists = get_type_container_lists(usau_soup)
# Out:
# [['Pool', 'Pool A Schedule & Scores'],
#  ['Pool', 'Pool B Schedule & Scores'],
#  ['Pool', 'Pool C Schedule & Scores'],
#  ['Pool', 'Pool D Schedule & Scores'],
#  ['Bracket', 'Crossover Round (4 Seeds from Pool Play)'],
#  ['Bracket', '1st Place Bracket'],
#  ['Bracket', '5th Place Bracket'],
#  ['Bracket', '7th Place Bracket - Pro Flight Play-In (A)'],
#  ['Bracket', '7th Place Bracket - Pro Flight Play-In (B)'],
#  ['Bracket', '11th Place Bracket'],
#  ['Bracket', '13th Place Bracket'],
#  ['Bracket', '15th Place Bracket']]

# %% [markdown]
# Looking good so far! Now we need to get the bracket position containers.

# %%
def type_subtype_lists_to_bracket_position_lists(type_subtype_lists):
    """Gets a list of bracket position containers from list of subtype containers."""
    containers = []
    
    for lst in type_subtype_lists:
        
        positions = lst[0].find_all(class_="bracket_col")
        
        # Find the bracket position containers inside of a given subtype container. If there are none, 
        # just return the original container with None for the bracket position.
        if not positions:
            containers.append([*lst, None])
            continue
        # If there are bracket position containers, iterate through them and make a new list for each.
        for bracket_position in positions:
            pos_name = bracket_position.find("h4", class_="col_title").text
            containers.append([bracket_position, *lst[1:], pos_name])

    return containers

pprint([container[1:] for container in type_subtype_lists_to_bracket_position_lists(type_subtype_lists)])
bracket_position_lists = type_subtype_lists_to_bracket_position_lists(type_subtype_lists)
# Out:
# [['Pool', 'Pool A Schedule & Scores', None],
#  ['Pool', 'Pool B Schedule & Scores', None],
#  ['Pool', 'Pool C Schedule & Scores', None],
#  ['Pool', 'Pool D Schedule & Scores', None],
#  ['Bracket', 'Crossover Round (4 Seeds from Pool Play)', None],
#  ['Bracket', '1st Place Bracket', 'Finals'],
#  ['Bracket', '1st Place Bracket', 'Semifinals'],
#  ['Bracket', '1st Place Bracket', 'Quarterfinals'],
#  ['Bracket', '1st Place Bracket', 'Pre-Quarterfinals'],
#  ['Bracket', '5th Place Bracket', '5th Place Finals'],
#  ['Bracket', '5th Place Bracket', '5th Place Semifinals'],
#  ['Bracket',
#   '7th Place Bracket - Pro Flight Play-In (A)',
#   'Pro Flight Play-In / 7th Place (tie)'],
#  ['Bracket',
#   '7th Place Bracket - Pro Flight Play-In (A)',
#   '9th Place Semifinals'],
#  ['Bracket',
#   '7th Place Bracket - Pro Flight Play-In (A)',
#   '9th Place Quarterfinals'],
#  ['Bracket',
#   '7th Place Bracket - Pro Flight Play-In (B)',
#   'Pro Flight Play-In / 7th Place (tie)'],
#  ['Bracket',
#   '7th Place Bracket - Pro Flight Play-In (B)',
#   '9th Place Semifinals'],
#  ['Bracket',
#   '7th Place Bracket - Pro Flight Play-In (B)',
#   '9th Place Quarterfinals'],
#  ['Bracket', '11th Place Bracket', '11th Place'],
#  ['Bracket', '13th Place Bracket', '13th Place Finals'],
#  ['Bracket', '13th Place Bracket', '13th Place Semifinals'],
#  ['Bracket', '15th Place Bracket', '15th Place']]

# %% [markdown]
# Finally, we need to get each game inside the bracket position containers. To do this, we'll search for the two relevant attributes: `data-game` and `data-relation`.

# %%
def bracket_position_lists_to_games(bracket_position_lists):
    """Gets list of games from list of bracket position containers."""
    games = []
    for bracket_position in bracket_position_lists:
        
        for game in bracket_position[0].find_all(attrs={"data-game":True}) + bracket_position[0].find_all(attrs={"data-relation":True}):
            games.append([game, *bracket_position[1:]])
    
    return games

games_list = bracket_position_lists_to_games(bracket_position_lists)
pprint([lst[1:] for lst in games_list])
# Out:
# [['Pool', 'Pool A Schedule & Scores', None],
#  ['Pool', 'Pool A Schedule & Scores', None],
#  ['Pool', 'Pool A Schedule & Scores', None],
#  ['Pool', 'Pool A Schedule & Scores', None],
#  ['Pool', 'Pool A Schedule & Scores', None],
#  ['Pool', 'Pool A Schedule & Scores', None],
#  ['Pool', 'Pool B Schedule & Scores', None],
#  ['Pool', 'Pool B Schedule & Scores', None],
#  ['Pool', 'Pool B Schedule & Scores', None],
#  ['Pool', 'Pool B Schedule & Scores', None],
#  ['Pool', 'Pool B Schedule & Scores', None],
#  ['Pool', 'Pool B Schedule & Scores', None],
#  ['Pool', 'Pool C Schedule & Scores', None],
#  ['Pool', 'Pool C Schedule & Scores', None],
#  ['Pool', 'Pool C Schedule & Scores', None],
#  ['Pool', 'Pool C Schedule & Scores', None],
#  ['Pool', 'Pool C Schedule & Scores', None],
#  ['Pool', 'Pool C Schedule & Scores', None],
#  ['Pool', 'Pool D Schedule & Scores', None],
#  ['Pool', 'Pool D Schedule & Scores', None],
#  ['Pool', 'Pool D Schedule & Scores', None],
#  ['Pool', 'Pool D Schedule & Scores', None],
#  ['Pool', 'Pool D Schedule & Scores', None],
#  ['Pool', 'Pool D Schedule & Scores', None],
#  ['Bracket', 'Crossover Round (4 Seeds from Pool Play)', None],
#  ['Bracket', 'Crossover Round (4 Seeds from Pool Play)', None],
#  ['Bracket', '1st Place Bracket', 'Finals'],
#  ['Bracket', '1st Place Bracket', 'Semifinals'],
#  ['Bracket', '1st Place Bracket', 'Semifinals'],
#  ['Bracket', '1st Place Bracket', 'Quarterfinals'],
#  ['Bracket', '1st Place Bracket', 'Quarterfinals'],
#  ['Bracket', '1st Place Bracket', 'Quarterfinals'],
#  ['Bracket', '1st Place Bracket', 'Quarterfinals'],
#  ['Bracket', '1st Place Bracket', 'Pre-Quarterfinals'],
#  ['Bracket', '1st Place Bracket', 'Pre-Quarterfinals'],
#  ['Bracket', '1st Place Bracket', 'Pre-Quarterfinals'],
#  ['Bracket', '1st Place Bracket', 'Pre-Quarterfinals'],
#  ['Bracket', '5th Place Bracket', '5th Place Finals'],
#  ['Bracket', '5th Place Bracket', '5th Place Semifinals'],
#  ['Bracket', '5th Place Bracket', '5th Place Semifinals'],
#  ['Bracket',
#   '7th Place Bracket - Pro Flight Play-In (A)',
#   'Pro Flight Play-In / 7th Place (tie)'],
#  ['Bracket',
#   '7th Place Bracket - Pro Flight Play-In (A)',
#   '9th Place Semifinals'],
#  ['Bracket',
#   '7th Place Bracket - Pro Flight Play-In (A)',
#   '9th Place Quarterfinals'],
#  ['Bracket',
#   '7th Place Bracket - Pro Flight Play-In (A)',
#   '9th Place Quarterfinals'],
#  ['Bracket',
#   '7th Place Bracket - Pro Flight Play-In (B)',
#   'Pro Flight Play-In / 7th Place (tie)'],
#  ['Bracket',
#   '7th Place Bracket - Pro Flight Play-In (B)',
#   '9th Place Semifinals'],
#  ['Bracket',
#   '7th Place Bracket - Pro Flight Play-In (B)',
#   '9th Place Quarterfinals'],
#  ['Bracket',
#   '7th Place Bracket - Pro Flight Play-In (B)',
#   '9th Place Quarterfinals'],
#  ['Bracket', '11th Place Bracket', '11th Place'],
#  ['Bracket', '13th Place Bracket', '13th Place Finals'],
#  ['Bracket', '13th Place Bracket', '13th Place Semifinals'],
#  ['Bracket', '13th Place Bracket', '13th Place Semifinals'],
#  ['Bracket', '15th Place Bracket', '15th Place']]

# %% [markdown]
# We can verify that we have the expected games in this list. Now we need to actually parse the games!

# %% [markdown]
# ## 4.5 Parsing the games

# %% [markdown]
# For Pandas, we will want to take each game and return a list containing the values that we want in each column. This list will end up being one row of the resulting dataframe. To recap, we wanted to find:
#
#
#     TN: Tournament name
#     GT: Game type (pool play or bracket play)
#     GST: Game subtype (pool number, 1st place bracket, crossover play)
#     BP: Bracket position (None for pool play, else quarterfinals / semifinals / etc.)
#     D: Date
#     T: Time
#     F: Field number
#     H: Home team
#     HSd: Home seed
#     HS: Home score
#     A: Away team
#     ASd: Away seed
#     AS: Away score
#
# We have taken care of the first four items already, since they are not contained in the actual game containers. Thankfully, it's not so hard to get the remaining items. For the most part, we can just call attributes. See the appendix for an explanation of the Regex.
#
# One more note: when we talk about building a dataframe row, we really mean building a nested list where each entry is a list containing the values of a given row. Pandas dataframe construction is much faster all at once than iteratively, so storing things as nested lists until all the information is gathered is better. See https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.append.html for a snippet on this.

# %%
def get_team_name_and_seed(raw_string):
    """Converts a raw team string to team name and seed number."""
    try:
        return re.search(r"\n?([^\(]*) \((\d*)", raw_string).groups()
    except:
        # Sometimes there is no listed name for the team, just a seed. To handle this,
        # we're just calling the team "Unknown (seed)", and including the seed number as usual.
        if re.match(r"\n?\(\d+\)", raw_string):
            stripped = raw_string.replace('\n', '') # removes newline characters
            return f"Unknown {stripped}", re.match(r"\n?.*(\d+)", raw_string).groups()[0]
        else:
            print(repr(raw_string))
            return raw_string, None

def get_teams_and_results(game_container):
    """Gets the team names, seeds, and scores from a game container."""
    home = game_container.find(attrs={"data-type":"game-team-home"}).text

    H, HSd = get_team_name_and_seed(home)
    HS = game_container.find(attrs={"data-type":"game-score-home"}).text

    away = game_container.find(attrs={"data-type":"game-team-away"}).text

    A, ASd = get_team_name_and_seed(away)
    AS = game_container.find(attrs={"data-type":"game-score-away"}).text
    
    return H,HSd,HS,A,ASd,AS

def game_to_df_row(game_list, TN, yr): # (Tournament Name), Year
    """Converts a game list to a list of dataframe row lists."""
    game_container, GT, GST, BP = game_list
    
    if "data-game" in game_container.attrs: #HANDLES POOL FORMATTING
        raw_date = game_container.find(attrs={"data-type":"game-date"}).text
        py_date = time.strptime(raw_date, "%a %m/%d") 
        # Uses the time package to interpret a string a date. The string "%a %m/%d"
        # tells Python to expect the format "<3-letter day abbreviation> <month in digits>/<day in digits>",
        # for example, "Thu 9/25".
        D = time.strftime(f"%m/%d/{yr}",py_date)
        # Converts the time to a uniform string format, for us, "month/day/year". Since we don't
        # get the year directly from the container, we pass it in as an argument to the function like
        # the tournament name.
        
        try:
            T = game_container.find(attrs={"data-type":"game-time"}).text
        except:
            T = None
        try:
            F = game_container.find(attrs={'data-type"game-field"':True}).text
        except:
            F = None
            
        H,HSd,HS,A,ASd,AS = get_teams_and_results(game_container)
    
    else:
        raw_date = game_container.find(class_="date", recursive=True).text
        try:
            py_date = time.strptime(raw_date, "%m/%d/%Y %I:%M %p") 
            D = time.strftime(f"%m/%d/{yr}",py_date)
            T = time.strftime(f"%I:%M %p",py_date)
        except:
            py_date = time.strptime(raw_date[:raw_date.find(" ")], "%m/%d/%Y") 
            D = time.strftime(f"%m/%d/{yr}",py_date)
            T = None
        try:
            F = game_container.find(class_="location").text
        except:
            F = None
       
        H,HSd,HS,A,ASd,AS = get_teams_and_results(game_container)
    

    
    return [TN,GT,GST,BP,D,T,F,H,HSd, HS,A, ASd,AS]


game_row_list = [game_to_df_row(game, "USA Ultimate National Championships", 2019) for game in games_list]

# %% [markdown]
# We can finally put these pieces together to read a tournament from a soup:

# %%
def read_tournament_from_soup(soup, year):
    """Get a list of game rows from a given tournament soup."""
    tournament_name = get_tournament_name(soup)
    print(tournament_name)
    type_subtype_lists = get_type_container_lists(soup)
    bracket_position_lists = type_subtype_lists_to_bracket_position_lists(type_subtype_lists)
    games_list = bracket_position_lists_to_games(bracket_position_lists)
    game_rows = [game_to_df_row(game, tournament_name, 2019) for game in games_list]
    return game_rows

# %% [markdown]
# At long last, we can actually make a dataframe for each tournament!

# %%
game_row_list = read_tournament_from_soup(usau_soup, 2019)
pd.DataFrame(game_row_list, columns=["TN","GT","GST","BP","D","T","F","H","HSd", "HS","A", "ASd","AS"])
# Out:
# USA Ultimate National Championships
#                                      TN       GT  \
# 0   USA Ultimate National Championships     Pool
# 1   USA Ultimate National Championships     Pool
# 2   USA Ultimate National Championships     Pool
# 3   USA Ultimate National Championships     Pool
# 4   USA Ultimate National Championships     Pool
# 5   USA Ultimate National Championships     Pool
# 6   USA Ultimate National Championships     Pool
# 7   USA Ultimate National Championships     Pool
# 8   USA Ultimate National Championships     Pool
# 9   USA Ultimate National Championships     Pool
# 10  USA Ultimate National Championships     Pool
# 11  USA Ultimate National Championships     Pool
# 12  USA Ultimate National Championships     Pool
# 13  USA Ultimate National Championships     Pool
# 14  USA Ultimate National Championships     Pool
# 15  USA Ultimate National Championships     Pool
# 16  USA Ultimate National Championships     Pool
# 17  USA Ultimate National Championships     Pool
# 18  USA Ultimate National Championships     Pool
# 19  USA Ultimate National Championships     Pool
# 20  USA Ultimate National Championships     Pool
# 21  USA Ultimate National Championships     Pool
# 22  USA Ultimate National Championships     Pool
# 23  USA Ultimate National Championships     Pool
# 24  USA Ultimate National Championships  Bracket
# 25  USA Ultimate National Championships  Bracket
# 26  USA Ultimate National Championships  Bracket
# 27  USA Ultimate National Championships  Bracket
# 28  USA Ultimate National Championships  Bracket
# 29  USA Ultimate National Championships  Bracket
# 30  USA Ultimate National Championships  Bracket
# 31  USA Ultimate National Championships  Bracket
# 32  USA Ultimate National Championships  Bracket
# 33  USA Ultimate National Championships  Bracket
# 34  USA Ultimate National Championships  Bracket
# 35  USA Ultimate National Championships  Bracket
# 36  USA Ultimate National Championships  Bracket
# 37  USA Ultimate National Championships  Bracket
# 38  USA Ultimate National Championships  Bracket
# 39  USA Ultimate National Championships  Bracket
# 40  USA Ultimate National Championships  Bracket
# 41  USA Ultimate National Championships  Bracket
# 42  USA Ultimate National Championships  Bracket
# 43  USA Ultimate National Championships  Bracket
# 44  USA Ultimate National Championships  Bracket
# 45  USA Ultimate National Championships  Bracket
# 46  USA Ultimate National Championships  Bracket
# 47  USA Ultimate National Championships  Bracket
# 48  USA Ultimate National Championships  Bracket
# 49  USA Ultimate National Championships  Bracket
# 50  USA Ultimate National Championships  Bracket
# 51  USA Ultimate National Championships  Bracket
# 52  USA Ultimate National Championships  Bracket
#
#                                            GST  \
# 0                     Pool A Schedule & Scores
# 1                     Pool A Schedule & Scores
# 2                     Pool A Schedule & Scores
# 3                     Pool A Schedule & Scores
# 4                     Pool A Schedule & Scores
# 5                     Pool A Schedule & Scores
# 6                     Pool B Schedule & Scores
# 7                     Pool B Schedule & Scores
# 8                     Pool B Schedule & Scores
# 9                     Pool B Schedule & Scores
# 10                    Pool B Schedule & Scores
# 11                    Pool B Schedule & Scores
# 12                    Pool C Schedule & Scores
# 13                    Pool C Schedule & Scores
# 14                    Pool C Schedule & Scores
# 15                    Pool C Schedule & Scores
# 16                    Pool C Schedule & Scores
# 17                    Pool C Schedule & Scores
# 18                    Pool D Schedule & Scores
# 19                    Pool D Schedule & Scores
# 20                    Pool D Schedule & Scores
# 21                    Pool D Schedule & Scores
# 22                    Pool D Schedule & Scores
# 23                    Pool D Schedule & Scores
# 24    Crossover Round (4 Seeds from Pool Play)
# 25    Crossover Round (4 Seeds from Pool Play)
# 26                           1st Place Bracket
# 27                           1st Place Bracket
# 28                           1st Place Bracket
# 29                           1st Place Bracket
# 30                           1st Place Bracket
# 31                           1st Place Bracket
# 32                           1st Place Bracket
# 33                           1st Place Bracket
# 34                           1st Place Bracket
# 35                           1st Place Bracket
# 36                           1st Place Bracket
# 37                           5th Place Bracket
# 38                           5th Place Bracket
# 39                           5th Place Bracket
# 40  7th Place Bracket - Pro Flight Play-In (A)
# 41  7th Place Bracket - Pro Flight Play-In (A)
# 42  7th Place Bracket - Pro Flight Play-In (A)
# 43  7th Place Bracket - Pro Flight Play-In (A)
# 44  7th Place Bracket - Pro Flight Play-In (B)
# 45  7th Place Bracket - Pro Flight Play-In (B)
# 46  7th Place Bracket - Pro Flight Play-In (B)
# 47  7th Place Bracket - Pro Flight Play-In (B)
# 48                          11th Place Bracket
# 49                          13th Place Bracket
# 50                          13th Place Bracket
# 51                          13th Place Bracket
# 52                          15th Place Bracket
#
#                                       BP           D         T        F  \
# 0                                   None  10/24/2019   9:00 AM       11
# 1                                   None  10/24/2019   9:00 AM       12
# 2                                   None  10/24/2019  11:15 AM       11
# 3                                   None  10/24/2019  11:15 AM       12
# 4                                   None  10/24/2019   1:30 PM       11
# 5                                   None  10/24/2019   1:30 PM        5
# 6                                   None  10/24/2019  11:15 AM        9
# 7                                   None  10/24/2019  11:15 AM       10
# 8                                   None  10/24/2019   1:30 PM        9
# 9                                   None  10/24/2019   1:30 PM       10
# 10                                  None  10/24/2019   3:45 PM        9
# 11                                  None  10/24/2019   3:45 PM       10
# 12                                  None  10/24/2019   9:00 AM        9
# 13                                  None  10/24/2019   9:00 AM       10
# 14                                  None  10/24/2019   1:30 PM       12
# 15                                  None  10/24/2019   1:30 PM       14
# 16                                  None  10/24/2019   3:45 PM        6
# 17                                  None  10/24/2019   3:45 PM       12
# 18                                  None  10/24/2019   9:00 AM        5
# 19                                  None  10/24/2019   9:00 AM       18
# 20                                  None  10/24/2019  11:15 AM        3
# 21                                  None  10/24/2019  11:15 AM       18
# 22                                  None  10/24/2019   3:45 PM        4
# 23                                  None  10/24/2019   3:45 PM       11
# 24                                  None  10/25/2019   9:00 AM       13
# 25                                  None  10/25/2019   9:00 AM       14
# 26                                Finals  10/27/2019  12:30 PM  Stadium
# 27                            Semifinals  10/26/2019  08:00 PM  Stadium
# 28                            Semifinals  10/26/2019  05:30 PM  Stadium
# 29                         Quarterfinals  10/25/2019  11:45 AM        5
# 30                         Quarterfinals  10/25/2019  11:45 AM        1
# 31                         Quarterfinals  10/25/2019  02:00 PM        7
# 32                         Quarterfinals  10/25/2019  02:00 PM        6
# 33                     Pre-Quarterfinals  10/25/2019  09:00 AM        9
# 34                     Pre-Quarterfinals  10/25/2019  09:00 AM       10
# 35                     Pre-Quarterfinals  10/25/2019  09:00 AM       17
# 36                     Pre-Quarterfinals  10/25/2019  09:00 AM       18
# 37                      5th Place Finals  10/26/2019  09:00 AM       16
# 38                  5th Place Semifinals  10/25/2019  04:15 PM       15
# 39                  5th Place Semifinals  10/25/2019  04:15 PM        6
# 40  Pro Flight Play-In / 7th Place (tie)  10/26/2019  09:00 AM        4
# 41                  9th Place Semifinals  10/25/2019  04:15 PM       13
# 42               9th Place Quarterfinals  10/25/2019  11:45 AM       15
# 43               9th Place Quarterfinals  10/25/2019  11:45 AM       16
# 44  Pro Flight Play-In / 7th Place (tie)  10/26/2019  09:00 AM       18
# 45                  9th Place Semifinals  10/25/2019  04:15 PM       14
# 46               9th Place Quarterfinals  10/25/2019  11:45 AM       13
# 47               9th Place Quarterfinals  10/25/2019  11:45 AM       14
# 48                            11th Place  10/26/2019  09:00 AM       17
# 49                     13th Place Finals  10/26/2019  09:00 AM       14
# 50                 13th Place Semifinals  10/25/2019  02:00 PM       13
# 51                 13th Place Semifinals  10/25/2019  02:00 PM       14
# 52                            15th Place  10/26/2019  11:15 AM       18
#
#                     H HSd  HS                  A ASd  AS
# 0             Sockeye   1  15      SoCal Condors  12  10
# 1                 DiG   8  15     Furious George  13   8
# 2             Sockeye   1  15     Furious George  13   8
# 3                 DiG   8  12      SoCal Condors  12  11
# 4             Sockeye   1  13                DiG   8  12
# 5       SoCal Condors  12  14     Furious George  13  11
# 6                PoNY   2  15  Pittsburgh Temper  11   8
# 7            Sub Zero   7  15       Johnny Bravo  14  12
# 8                PoNY   2  14       Johnny Bravo  14   6
# 9            Sub Zero   7  15  Pittsburgh Temper  11  13
# 10               PoNY   2  14           Sub Zero   7  13
# 11  Pittsburgh Temper  11  15       Johnny Bravo  14  13
# 12         Truck Stop   3  15               GOAT  10   7
# 13    Chicago Machine   6  12    Chain Lightning  15  15
# 14         Truck Stop   3  15    Chain Lightning  15   7
# 15    Chicago Machine   6  15               GOAT  10   6
# 16         Truck Stop   3  14    Chicago Machine   6  15
# 17               GOAT  10  15    Chain Lightning  15  11
# 18       Ring of Fire   4  13         Doublewide   9  14
# 19           Revolver   5  15        Rhino Slam!  16  10
# 20       Ring of Fire   4  15        Rhino Slam!  16   5
# 21           Revolver   5  15         Doublewide   9  14
# 22       Ring of Fire   4  15           Revolver   5   9
# 23         Doublewide   9  11        Rhino Slam!  16  15
# 24         Doublewide   9  10    Chain Lightning  15  15
# 25     Furious George  13  11       Johnny Bravo  14  15
# 26            Sockeye   1  13    Chicago Machine   6  12
# 27            Sockeye   1  14       Ring of Fire   4  13
# 28    Chicago Machine   6  15               PoNY   2  10
# 29            Sockeye   1  15           Sub Zero   7   9
# 30         Truck Stop   3  12       Ring of Fire   4  15
# 31    Chicago Machine   6  15           Revolver   5  13
# 32        Rhino Slam!  16  14               PoNY   2  15
# 33           Sub Zero   7  15               GOAT  10  12
# 34  Pittsburgh Temper  11  13         Truck Stop   3  15
# 35           Revolver   5  15      SoCal Condors  12  13
# 36        Rhino Slam!  16  15                DiG   8  12
# 37         Truck Stop   3  15           Revolver   5  12
# 38         Truck Stop   3  15        Rhino Slam!  16   7
# 39           Revolver   5  15           Sub Zero   7  12
# 40        Rhino Slam!  16  15         Doublewide   9  13
# 41         Doublewide   9  16      SoCal Condors  12  15
# 42                DiG   8  14         Doublewide   9  15
# 43    Chain Lightning  15  13      SoCal Condors  12  14
# 44     Furious George  13  13           Sub Zero   7  14
# 45  Pittsburgh Temper  11  13     Furious George  13  15
# 46  Pittsburgh Temper  11  15       Johnny Bravo  14  12
# 47     Furious George  13  15               GOAT  10   8
# 48      SoCal Condors  12  15  Pittsburgh Temper  11  13
# 49                DiG   8  12               GOAT  10  15
# 50                DiG   8  15    Chain Lightning  15  14
# 51       Johnny Bravo  14   8               GOAT  10  15
# 52    Chain Lightning  15  11       Johnny Bravo  14  14

# %% [markdown]
# Let's put it all together. Since we've been making all of these functions as we go, this is pretty simple!

# %%
def read_year(year=2019, division="club-open", links=None):
    """Read a year into a dataframe of games."""
    if links is None:
        print("Getting tournaments...")
        links = year_to_tournaments(year, division)
    game_rows_full = []
    print("Reading tournaments...")
    for link in tqdm(links, position=0):
        tournament_data = requests.get(link)
        tournament_soup = BeautifulSoup(tournament_data.text, 'html.parser')
        game_rows = read_tournament_from_soup(tournament_soup, year)
        game_rows_full.extend(game_rows)
    df = pd.DataFrame(game_rows_full, columns=["TN","GT","GST","BP","D","T","F","H","HSd", "HS","A", "ASd","AS"])
    return df

# %%
df = read_year(2019, links=usau_links)
df
# Out:
# here
#   0%|          | 0/72 [00:00<?, ?it/s]
# 31st Annual Red Tide Ultimate Clambake
# <built-in function repr>
# <built-in function repr>
# <built-in function repr>
# <built-in function repr>
# <built-in function repr>
# <built-in function repr>
# USA Ultimate National Championships
# Southwest Club Men's Regional Championship 2019
# Southeast Club Men's Regional Championship 2019
# South Central Club Men's Regional Championship 2019
# Northwest Club Men's Regional Championship 2019
# Northeast Club Men's Regional Championship 2019
# North Central Club Men's Regional Championship 2019
# Mid-Atlantic Men's Club Regional Championship 2019
# Great Lakes Men's Club Regional Championship
# Nor Cal Men's Club Sectional Championship 2019
# West Plains Men's Club Sectional Championship 2019
# West New England Men's Club Sectional Championship 2019
# Washington Men's Club Sectional Championship 2019
# Upstate New York Men's Club Sectional Championship 2019
# Texas Men's Club Sectional Championship 2019
# So Cal Men's Club Sectional Championship 2019
# Rocky Mountain Men's Club Sectional Championship 2019
# Ozarks Men's Club Sectional Championship 2019
# Oregon Men's Club Sectional Championship 2019
# Northwest Plains Men's Club Sectional Championship 2019
# <built-in function repr>
# <built-in function repr>
# <built-in function repr>
# <built-in function repr>
# <built-in function repr>
# <built-in function repr>
# <built-in function repr>
# <built-in function repr>
# North Carolina Men's Club Sectional Championship 2019
# Metro New York Men's Club Sectional Championship 2019
# Gulf Coast Men's Club Sectional Championship 2019
# Founders Men's Club Sectional Championship 2019
# Florida Men's Club Sectional Championship 2019
# East Plains Men's Club Sectional Championship 2019
# East New England Men's Club Sectional Championship 2019
# East Coast Men's Club Sectional Championship 2019
# Central Plains Men's Club Sectional Championship 2019
# Capital Men's Club Sectional Championship 2019
# Big Sky Men's Club Sectional Championship 2019
# TCT Pro Championships 2019
# Labor Day (Recreational Tournament)
# 'W of Round Name G1'
# 'W of Round Name G2'
# The Incident 2019: Age of Ultimatron
# Ski Town Classic 2019
# Indy Invite Club 2019
# FCS Invite 2019
# TCT Elite-Select Challenge 2019
# Mudbowl 2019
# Hootie on the Hill 2019
# Cooler Classic 31
# Nucci's Cup 2019
# Chesapeake Open 2019
# Philly Open 2019
# Heavyweights 2019
# CBR 2019
# 2019 U.S. Open Club Championship
# PB&J 2019
# Angel City Shootout 2019
# Vacationland 2019
# The Royal Experience 2019
# 2019 Club Terminus
# Stonewalled 2019
# The Bropen 2019
# TCT Select Flight Invite - East 2019
# TCT Pro-Elite Challenge (Colorado Cup) 2019
# Swan Boat 2019
# Riverside Classic 2019
# Ow My Knee
# OK Corral 2019
# Motown Throwdown 2019
# Huntsville Huckfest 2019
# AntlerLock 2019
# Texas 2 Finger - Men's and Women's
# Spirit of the Plains 2019
# SCINNY 2019
# Fort Collins Summer Solstice 2019
# Eugene Summer Solstice 2019
# Boston Invite 2019
# San Diego Slammer 2019
# ATL Classic 2019
#                                           TN       GT  \
# 0     31st Annual Red Tide Ultimate Clambake     Pool
# 1     31st Annual Red Tide Ultimate Clambake     Pool
# 2     31st Annual Red Tide Ultimate Clambake     Pool
# 3     31st Annual Red Tide Ultimate Clambake     Pool
# 4     31st Annual Red Tide Ultimate Clambake     Pool
# ...                                      ...      ...
# 2600                        ATL Classic 2019  Bracket
# 2601                        ATL Classic 2019  Bracket
# 2602                        ATL Classic 2019  Bracket
# 2603                        ATL Classic 2019  Bracket
# 2604                        ATL Classic 2019  Bracket
#
#                            GST         BP           D         T        F  \
# 0     Pool A Schedule & Scores       None  10/26/2019  11:30 AM      W05
# 1     Pool A Schedule & Scores       None  10/26/2019  11:30 AM      W17
# 2     Pool A Schedule & Scores       None  10/26/2019   1:00 PM      W05
# 3     Pool A Schedule & Scores       None  10/26/2019   1:00 PM      W17
# 4     Pool A Schedule & Scores       None  10/26/2019   2:30 PM      W05
# ...                        ...        ...         ...       ...      ...
# 2600         1st Place Bracket     Finals  06/16/2019  01:30 PM   GSP #7
# 2601         1st Place Bracket      Semis  06/16/2019  10:10 AM  GSP #10
# 2602         1st Place Bracket      Semis  06/16/2019  10:10 AM  GSP #11
# 2603         1st Place Bracket  Pre-Semis  06/16/2019  08:30 AM  GSP #10
# 2604         1st Place Bracket  Pre-Semis  06/16/2019  08:30 AM  GSP #11
#
#                       H HSd  HS                A ASd  AS
# 0     yEUTH-ANd-Age-SIA   1  15  Unknown \n(7)\n   7   6
# 1       Unknown \n(6)\n   6   0          Bowdoin  12   0
# 2     yEUTH-ANd-Age-SIA   1   0          Bowdoin  12   0
# 3       Unknown \n(6)\n   6   0  Unknown \n(7)\n   7   0
# 4     yEUTH-ANd-Age-SIA   1   0  Unknown \n(6)\n   6   0
# ...                 ...  ..  ..              ...  ..  ..
# 2600             Freaks   1  11          El Niño   2  12
# 2601             Freaks   1  11           Bullet   3  10
# 2602            El Niño   2  12          ATLiens   9  11
# 2603             Bullet   3  10          Ironmen   4   8
# 2604            ATLiens   9  11  H.O.G. Ultimate   5   6
#
# [2605 rows x 13 columns]

# %%
df.to_csv("2019_club_open.csv")
odf = df.copy()

# %% [markdown]
# And there we go! That's everything!

# %% [markdown]
# # 5 A bit of fun with rankings

# %% [markdown]
# Since this is slightly beyond scope we won't get too deep into this, but here is the code that converts this dataframe into a set of rankings.

# %%
def get_teams(df):
    """Get a list of all teams in dataframe."""
    teams = df[["H","A"]].melt()["value"].unique()
    index_to_name = dict(enumerate(teams))
    name_to_index = dict([(index_to_name[i], i) for i in index_to_name])
    return teams, index_to_name, name_to_index

def clean_df(df):
    """Cleans dataframe to remove undesirable rows."""
    df = df.fillna("None")
    
    df["HS"] = df["HS"].replace(["W","L","F"], np.nan)
    df["AS"] = df["AS"].replace(["W","L","F"], np.nan)
    # We ignore games that don't have listed score differentials.
    df.dropna(inplace=True)
    df["HS"] = df["HS"].astype(int)
    df["AS"] = df["AS"].astype(int)
    
    df = df[~((df["HS"]==0) & (df["AS"] == 0))]
    # ignore games that were not played (both scores 0)
    df = df.reset_index(drop=True)
    return df

def make_incidence_matrix(df, zerosum=False):
    """Makes incidence matrix and score vector from dataframe."""
    teams, index_to_name, name_to_index = get_teams(df)
    m = len(df)
    n = len(teams)
    A = np.zeros((m,n))
    b = np.zeros((m,1))
    
    for i, row in df.iterrows():
        home = name_to_index[row["H"]]
        away = name_to_index[row["A"]]
        A[i, home] = 1
        A[i, away] = -1
        b[i] = row["HS"] - row["AS"]
        b[i] = b[i] + np.sign(b[i])
        ### GIVES THE WINNING TEAM ONE EXTRA POINT!
    return A,b

def get_sort(ratings, index_to_name):
    """Sorts a rating vector into (team name, rating) tuples."""
    team_ratings = [(index_to_name[i], j.item()) for i,j in enumerate(ratings)]
    return sorted(team_ratings, key=itemgetter(1), reverse=True)  
 
def display_sort_list(sort_list):
    """Displays ranked list of teams from sorted tuple list."""
    for i, tup in enumerate(sort_list):
        print(f"{i+1}. {tup[0]} | {tup[1]*100:.0f}")
        # Ratings multiplied by 100 for readability
    
def find_team(df, team):
    "Utility function: returns all games that a given team played in."
    return df[np.any(df[["H","A"]] == team, axis=1)]

# %%
df = clean_df(df)
teams, index_to_name, name_to_index = get_teams(df)
A,b = make_incidence_matrix(df)
x = np.linalg.lstsq(A,b,rcond=None)[0]
sort_list = get_sort(x, index_to_name)
display_sort_list(sort_list)
# Out:
# 1. Sockeye | 1604
# 2. Truck Stop | 1599
# 3. Ring of Fire | 1517
# 4. PoNY | 1476
# 5. Revolver | 1423
# 6. Chicago Machine | 1399
# 7. Sub Zero | 1349
# 8. DiG | 1312
# 9. Nomadic Tribe | 1300
# 10. GOAT | 1248
# 11. SoCal Condors | 1235
# 12. Pittsburgh Temper | 1212
# 13. Furious George | 1196
# 14. Bunka Shutter Buzz Bullets | 1171
# 15. Doublewide | 1163
# 16. Chain Lightning | 1134
# 17. Johnny Bravo | 1116
# 18. Sprout | 1114
# 19. Yogosbo | 1016
# 20. Rhino Slam! | 1013
# 21. Voodoo | 975
# 22. Brickyard | 908
# 23. Patrol | 875
# 24. General Strike | 867
# 25. Vault | 848
# 26. CLE Smokestack | 838
# 27. H.I.P | 788
# 28. NexGen All-Star Tour | 772
# 29. Prairie Fire | 753
# 30. Nain Rouge | 742
# 31. Clutch | 740
# 32. yEUTH-ANd-Age-SIA | 733
# 33. Brickhouse | 731
# 34. Johnny Encore | 728
# 35. Freaks | 702
# 36. Black Market I | 698
# 37. Nitro | 680
# 38. Mad Men | 678
# 39. Blueprint | 678
# 40. Lost Boys | 665
# 41. MKE | 660
# 42. Garden State Ultimate | 653
# 43. Phoenix | 636
# 44. Blackfish | 614
# 45. CITYWIDE Special | 613
# 46. Tanasi | 605
# 47. Slugfest | 600
# 48. UpRoar | 599
# 49. Shade | 595
# 50. Haymaker | 592
# 51. Red Dawn | 587
# 52. Mallard | 582
# 53. Inception | 579
# 54. Ghost Train | 574
# 55. El Niño | 565
# 56. The Killjoys | 552
# 57. OAT | 535
# 58. Cryptic | 507
# 59. Colt  | 486
# 60. Battery | 483
# 61. Lantern | 480
# 62. Genny, The Boys | 479
# 63. Guerrilla | 479
# 64. Red Circus | 462
# 65. Sundowners | 428
# 66. Scythe | 428
# 67. Comunidad El Oso | 426
# 68. Gaucho | 424
# 69. Sawtooth | 414
# 70. Ironmen | 408
# 71. Big Wrench | 404
# 72. Dohrk Stor | 393
# 73. Swans | 389
# 74. Streetgang | 373
# 75. DNA | 369
# 76. Mango Tree | 364
# 77. Deathsquad | 356
# 78. Gamble | 341
# 79. Turbine | 340
# 80. DeMo | 339
# 81. Texas United | 303
# 82. Dark Star | 297
# 83. Minnesota Superior U20B | 284
# 84. ATLiens | 280
# 85. Dreadnought | 276
# 86. Black Lung | 275
# 87. Bullet | 272
# 88. ISO Atmo | 268
# 89. Omen | 262
# 90. Riverside | 260
# 91. MAKAWUA  | 259
# 92. SOUF | 248
# 93. Log Jam | 241
# 94. Town Hall Stars | 232
# 95. Rumspringa | 220
# 96. Club M - Manic | 218
# 97. Richmond Floodwall | 206
# 98. Harvey Cats | 201
# 99. THE BODY | 198
# 100. Magma Bears | 190
# 101. Red Tide | 183
# 102. John Doe | 173
# 103. Black Market II | 157
# 104. PowderHogs | 156
# 105. Chuck Wagon | 150
# 106. Red Hots - u20 | 145
# 107. Low Point | 130
# 108. Green River Swordfish | 125
# 109. Imperial | 123
# 110. Burly | 113
# 111. HouSE | 109
# 112. Bash Bros | 107
# 113. Charleston Heat Stroke | 102
# 114. Fathom | 101
# 115. Seattle Blacklist | 98
# 116. Johnny Walker | 94
# 117. Papa Bear | 93
# 118. H.O.G. Ultimate | 76
# 119. Satellite  | 75
# 120. Timber | 71
# 121. Unknown
# (9)
#  | 66
# 122. Somerville BAG | 63
# 123. Choice City Hops | 50
# 124. Shrike | 48
# 125. Rush Hour ATL | 40
# 126. Swamp Horse | 25
# 127. Oregon Eruption! | 20
# 128. JAWN | 16
# 129. Green Means Bro | 13
# 130. Genny The Boys | 12
# 131. CaSTLe | 8
# 132. Dynasty | 0
# 133. Enigma | -0
# 134. Kentucky Flying Circus | -10
# 135. DOGGPOUND | -16
# 136. Vicious Cycle | -25
# 137. Slag Dump | -34
# 138. baNC | -36
# 139. Journeymen | -52
# 140. Overcast | -53
# 141. Rougaroux | -56
# 142. Cockfight | -70
# 143. Oakgrove Boys | -71
# 144. Space Coast Ultimate | -72
# 145. Kansas City Smokestack | -72
# 146. Foggy Bottom Boys | -73
# 147. ScooberDivers | -77
# 148. Babe | -110
# 149. Ditto A | -137
# 150. Space Cowboys | -139
# 151. Big Muscle Boys | -146
# 152. Syndicate | -153
# 153. Glycerine | -157
# 154. Unknown (9) | -160
# 155. BUDA U20B | -161
# 156. Watchdogs | -161
# 157. Regiment | -167
# 158. Colorado Cutthroat: Youth Club U-20 Boys | -167
# 159. Flash Flood | -176
# 160. Foxtrot | -189
# 161. Little Teapots | -196
# 162. Waste Management Squad | -203
# 163. Louisiana Second Line | -206
# 164. Ender's Outcasts | -214
# 165. SHRed Line | -217
# 166. Silence of the Clams | -217
# 167. Those Magnificent Bastards | -225
# 168. The Berkeley Bobcats | -244
# 169. DINGWOP | -248
# 170. Predator | -250
# 171. Supercell | -265
# 172. Unknown
# (7)
#  | -267
# 173. Boulder United Flatiron Hammers | -270
# 174. BlackER Market Y | -274
# 175. MomINtuM  | -276
# 176. Sherbrooke Gentlemen's Club | -282
# 177. Bomb Squad | -284
# 178. Old Ephraim | -287
# 179. Medicine Men | -296
# 180. Rising Tide U20B | -307
# 181. Cojones | -309
# 182. Not A Sport | -313
# 183. One Night | -314
# 184. Adelphos | -314
# 185. DUPlex | -316
# 186. White Sauce Hot Sauce | -338
# 187. Rock Steady | -350
# 188. Milwaukee Revival | -350
# 189. Club M - Magma | -353
# 190. Sandbaggers | -369
# 191. Barefoot | -371
# 192. Helots | -371
# 193. Rip City | -376
# 194. Red Bat | -380
# 195. Hazard | -386
# 196. Yacht Club | -396
# 197. OC Crows | -449
# 198. Chimney | -450
# 199. Carolina Sky | -456
# 200. Watch City | -458
# 201. UpRoar Claws | -459
# 202. Midnight Meat Train | -463
# 203. Bowdoin | -467
# 204. Trent's Team | -470
# 205. Arithmetic Ultimate | -478
# 206. Komori | -487
# 207. E.V.I.L. | -492
# 208. A-Block | -501
# 209. Goaltimate All Stars | -506
# 210. Fargoats | -511
# 211. Black Knights | -519
# 212. Winc City Fog of War | -519
# 213. Bates College | -525
# 214. Miner Magic | -530
# 215. Rawhide | -536
# 216. Battleship | -537
# 217. Kingdome | -545
# 218. Festive Salmon | -550
# 219. Rampage | -564
# 220. NEO | -569
# 221. Scootlyfe | -574
# 222. BlackER Market X | -580
# 223. Red Imp.ala | -589
# 224. Daybreak | -598
# 225. Madhouse | -621
# 226. Sky Hook | -621
# 227. Thunder Boys | -627
# 228. Flying Pig | -640
# 229. Hail Mary | -643
# 230. Alamode | -646
# 231. Villains | -651
# 232. Spring Break '93 | -655
# 233. War Machine | -655
# 234. Bearproof | -663
# 235. Tyranny | -676
# 236. Apollo 7 | -677
# 237. Gentlemen's Club | -680
# 238. Nasty Girls | -704
# 239. desert penguins | -706
# 240. Texas Heatwave | -737
# 241. Messengers | -747
# 242. Quaze | -749
# 243. Surrilic Audovice | -801
# 244. HB Woodlawn | -812
# 245. Genny Lite | -813
# 246. Maine | -817
# 247. Bird Patrol | -839
# 248. Flying Dutchmen | -853
# 249. Highlight Reel | -865
# 250. Tsunami B | -872
# 251. Traffic | -876
# 252. Fusion | -897
# 253. Texas Toast | -918
# 254. Hot Tamales  | -927
# 255. Fathom II | -973
# 256. Black Market III | -993
# 257. Gonzaga | -1000
# 258. Kettering | -1013
# 259. Ditto B | -1014
# 260. Philadelphia Padawans | -1053
# 261. Stuyvesant Sticky Fingers Alumni | -1060
# 262. Space Force | -1095
# 263. Axial Tilt | -1101
# 264. Huckleberry | -1115
# 265. Buffalo Open | -1130
# 266. defunCT | -1239
# 267. Bees | -1267
# 268. Identity Crisis | -1271
# 269. Cincinnati Flying Piglet | -1409
# 270. Neap Tide | -1563

# %% [markdown]
# # A.1 Regex explanation

# %% [markdown]
# Recall that our goal was to take a team string (e.g. "Sockeye (1)") and separate it into a team name and seed. Since there are a lot of weird team names, we use regex to handle this. Below is the original function:

# %%
def get_team_name_and_seed(raw_string):
    """Converts a raw team string to team name and seed number."""
    try:
        return re.search(r"\n?([^\(]*) \((\d*)", raw_string).groups()
    except:
        # Sometimes there is no listed name for the team, just a seed. To handle this,
        # we're just calling the team "Unknown (seed)", and including the seed number as usual.
        if re.match(r"\n?\(\d+\)", raw_string):
            stripped = raw_string.replace('\n', '') # removes newline characters
            return f"Unknown {stripped}", re.match(r"\n?.*(\d+)", raw_string).groups()[0]
        else:
            print(repr(raw_string))
            return raw_string, None

# %% [markdown]
# We'll start with the third line. This is looking for matches the search string, that roughly means:

# %% [markdown]
# \n : match the newline character
#
# ? : optional (0 or 1 occurrences)
#
# ( : a *capturing group*: when a match is found, this tells the compiler what group of characters to return.
#
# []: matches a specific group of characters
#
# ^ : negation (match all BUT these characters)
#
# \\( : raw open parenthesis (using the backslash to escape out of the capturing group above
#
# * : any number of occurences
#
# ) : closes the capture group
# So: [^\(]* means "Match any number of characters that are NOT an open parenthesis"
#
#  : raw whitespace
#
# \d: any digit character
#
# Now in larger terms, the whole string could be phrased as:
#
# "Match strings that may have a newline at the beginning, some number of characters, a space and an open parenthesis, and a digit at the end. Capture only the first non-parenthesis characters as well as the digits."

# %% [markdown]
# # A.2 Combined code

# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup, Comment
# BeautifulSoup (hereafter BS) and requests are the two main packages for normal web scraping.
# requests mainly actually gets you the source data, and BeautifulSoup lets
# you actually work with it?
import urllib3
import urllib.request
import matplotlib.pyplot as plt
import seaborn as sns
# Seaborn is a plotting package that can make things look nicer than Matplotlib, but is most useful
# since it works nicely with Pandas dataframes. I'm including it here as a standard import, at time
# of writing I'm not sure if it will be used or not. It's a nice thing to have though!

import itertools as it
import more_itertools as mit
# Not sure if we'll need either of these, but again, standard imports.

import json
import re
# This is the regex package. For those unfamiliar, regex is a "language" for
# very specific text searching and extraction. Check out https://regexone.com/
# for a tutorial / explanation. 
import io
import math
import time
import cProfile
from pprint import pprint
# Will be useful for demonstration
from tqdm.notebook import tqdm
# Will make nice progress bars

import selenium
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
# I am using Chrome here, there are other supported browsers out there too.
# I think Firefox is actually the more common one for this

chrome_options = Options()
chrome_options.add_argument("--headless")
# Headless stops a browser from being visibly opened on your computer.

driver = webdriver.Chrome(options=chrome_options, 
              executable_path=r"C:\Users\alexs\Projects\lls\chromedriver.exe")

# You will have to download the chromedriver.exe file and change this path to
# point at it.

def jspage_to_soup(url, scroll=True):
    """Visit a JavaScript page and convert it into a soup."""
    # This is all selenium code!
    chrome_options = Options()
    chrome_options.add_argument("--headless")

    # Headless stops a browser from being visibly opened on your computer.

    driver = webdriver.Chrome(options=chrome_options, 
                  executable_path=r"C:\Users\alexs\Projects\lls\chromedriver.exe")

    # You will have to download the chromedriver.exe file and change this path to
    # point at it.
   
    driver.get(url)
    # Visit the page with the driver!

    time.sleep(1.5)
    # !!! We need to give the page time to load!
    if scroll:
        for i in range(20):
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);\
                                  var lenOfPage=document.body.scrollHeight;\
                                  return lenOfPage;")
            time.sleep(1)
            # This process literally scrolls the page all the way down to make sure that all of the content
            # gets read and stored. We won't always need to do this (see below), so we add an option to control it.
    
    data = driver.page_source.encode("utf-8")
    # Takes the driver response and grabs the page source code including the javascript. This puts things in
    # a form that BS can handle.
    
    soup = BeautifulSoup(data, 'html.parser')
    # Makes the soup object!
    # Note: a soup object is essentially a version of the source code that has the nested tag HTML structure the
    # same way as if you look at a page in a browser inspector.
    return soup

def extract_tournament_info(tr_tag, division='club-open'):
    """Extract the tournament type and ultiarchive link from a tag."""
    tournament_type = tr_tag.find(class_="tournament-type").text
    links = ["https://ultiarchive.com" + tag['href'] for tag in tr_tag.find_all(href=True) if division in tag['href']]
    # Makes links to each tournament as long as the link contains the right division.
    return tournament_type, links

def soup_to_list_of_tournaments(soup, division='club-open'):
    """Turn an ultiarchive soup into a list of all ultiarchive tournament links."""
    all_links = []
    for tr_tag in soup.find_all("tr"):
        tournament_type, links = extract_tournament_info(tr_tag, division)
        if tournament_type == "usau":
            all_links.extend(links)
    return all_links

def year_to_tournaments(year=2019, division='club-open'):
    """ Gets links to each ultiarchive tournament page for a given year"""
    url = fr"https://ultiarchive.com/years/{year}"
    # This is the general form for the ultiarchive pages
    soup = jspage_to_soup(url)
    links = soup_to_list_of_tournaments(soup, division='club-open')
    return links

def ulti_to_usau(url):
    """Converts an Ultiarchive tournament link to the corresponding USAU tournament link."""
    soup = jspage_to_soup(url, scroll=False)
    return soup.find(href=True, rel="noopener")["href"]

def year_to_tournaments(year=2019, division='club-open'):
    """ Gets links to each ultiarchive tournament page for a given year"""
    url = fr"https://ultiarchive.com/years/{year}"
    # This is the general form for the ultiarchive pages
    soup = jspage_to_soup(url)
    links = soup_to_list_of_tournaments(soup, division='club-open')
    print(links[:10])
    print("Found links!")
    usau_links = []
    for link in tqdm(links, position=0):
        print(link)
        usau_links.append(ulti_to_usau(link))
    return usau_links

def get_tournament_name(soup):
    """Get the name of a tournament from a soup."""
    return list(soup.find(class_="breadcrumbs").children)[3].text

def get_subtype_container_lists(soup):
    """Gets list of all subtype containers from a tournament soup."""
    containers = []
    
    for subtype_container in soup.find_all(class_="global_table scores_table"): 
    # "Things that are stored as pool play, but may or may not ACTUALLY be pool play:"
        name = subtype_container.find("th", colspan="8").text
        containers.append([subtype_container, name])

    for subtype_container in soup.find_all(class_="mod_slide alt_slide"):
    # "Things that are stored as bracket play, but may or may not ACTUALLY be bracket play:"
        name = subtype_container.find(href="#").text
        containers.append([subtype_container, name])
    
    return containers

def subtype_name_to_type(subtype_name):
    """Determines whether a given subtype container name corresponds to pool or bracket play."""
    if not any([keyword in subtype_name.lower() for keyword in ["st", "nd", "rd", "th", "crossover"]])\
        and "pool" in subtype_name.lower():
        return "Pool"
    else:
        return "Bracket"

def subtype_lists_to_type_lists(subtype_lists):
    """Adds game types to list of subtype containers."""
    for lst in subtype_lists:
        lst.insert(1, subtype_name_to_type(lst[1]))
    return subtype_lists

def get_type_container_lists(soup):
    """Gets list of subtype containers with types from a tournament soup."""
    subtype_lists = get_subtype_container_lists(soup)
    return subtype_lists_to_type_lists(subtype_lists)

def type_subtype_lists_to_bracket_position_lists(type_subtype_lists):
    """Gets a list of bracket position containers from list of subtype containers."""
    containers = []
    
    for lst in type_subtype_lists:
        
        positions = lst[0].find_all(class_="bracket_col")
        
        # Find the bracket position containers inside of a given subtype container. If there are none, 
        # just return the original container with None for the bracket position.
        if not positions:
            containers.append([*lst, None])
            continue
        # If there are bracket position containers, iterate through them and make a new list for each.
        for bracket_position in positions:
            pos_name = bracket_position.find("h4", class_="col_title").text
            containers.append([bracket_position, *lst[1:], pos_name])

    return containers

def bracket_position_lists_to_games(bracket_position_lists):
    """Gets list of games from list of bracket position containers."""
    games = []
    for bracket_position in bracket_position_lists:
        
        for game in bracket_position[0].find_all(attrs={"data-game":True}) + bracket_position[0].find_all(attrs={"data-relation":True}):
            games.append([game, *bracket_position[1:]])
    
    return games

def get_team_name_and_seed(raw_string):
    """Converts a raw team string to team name and seed number."""
    try:
        return re.search(r"\n?([^\(]*) \((\d*)", raw_string).groups()
    except:
        # Sometimes there is no listed name for the team, just a seed. To handle this,
        # we're just calling the team "Unknown (seed)", and including the seed number as usual.
        if re.match(r"\n?\(\d+\)", raw_string):
            stripped = raw_string.replace('\n', '') # removes newline characters
            return f"Unknown {stripped}", re.match(r"\n?.*(\d+)", raw_string).groups()[0]
        else:
            print(repr(raw_string))
            return raw_string, None

def get_teams_and_results(game_container):
    """Gets the team names, seeds, and scores from a game container."""
    home = game_container.find(attrs={"data-type":"game-team-home"}).text

    H, HSd = get_team_name_and_seed(home)
    HS = game_container.find(attrs={"data-type":"game-score-home"}).text

    away = game_container.find(attrs={"data-type":"game-team-away"}).text

    A, ASd = get_team_name_and_seed(away)
    AS = game_container.find(attrs={"data-type":"game-score-away"}).text
    
    return H,HSd,HS,A,ASd,AS

def game_to_df_row(game_list, TN, yr): # (Tournament Name), Year
    """Converts a game list to a list of dataframe row lists."""
    game_container, GT, GST, BP = game_list
    
    if "data-game" in game_container.attrs: #HANDLES POOL FORMATTING
        raw_date = game_container.find(attrs={"data-type":"game-date"}).text
        py_date = time.strptime(raw_date, "%a %m/%d") 
        # Uses the time package to interpret a string a date. The string "%a %m/%d"
        # tells Python to expect the format "<3-letter day abbreviation> <month in digits>/<day in digits>",
        # for example, "Thu 9/25".
        D = time.strftime(f"%m/%d/{yr}",py_date)
        # Converts the time to a uniform string format, for us, "month/day/year". Since we don't
        # get the year directly from the container, we pass it in as an argument to the function like
        # the tournament name.
        
        try:
            T = game_container.find(attrs={"data-type":"game-time"}).text
        except:
            T = None
        try:
            F = game_container.find(attrs={'data-type"game-field"':True}).text
        except:
            F = None
            
        H,HSd,HS,A,ASd,AS = get_teams_and_results(game_container)
    
    else:
        raw_date = game_container.find(class_="date", recursive=True).text
        try:
            py_date = time.strptime(raw_date, "%m/%d/%Y %I:%M %p") 
            D = time.strftime(f"%m/%d/{yr}",py_date)
            T = time.strftime(f"%I:%M %p",py_date)
        except:
            py_date = time.strptime(raw_date[:raw_date.find(" ")], "%m/%d/%Y") 
            D = time.strftime(f"%m/%d/{yr}",py_date)
            T = None
        try:
            F = game_container.find(class_="location").text
        except:
            F = None
       
        H,HSd,HS,A,ASd,AS = get_teams_and_results(game_container)
    

    
    return [TN,GT,GST,BP,D,T,F,H,HSd, HS,A, ASd,AS]

def read_tournament_from_soup(soup, year):
    """Get a list of game rows from a given tournament soup."""
    tournament_name = get_tournament_name(soup)
    print(tournament_name)
    type_subtype_lists = get_type_container_lists(soup)
    bracket_position_lists = type_subtype_lists_to_bracket_position_lists(type_subtype_lists)
    games_list = bracket_position_lists_to_games(bracket_position_lists)
    game_rows = [game_to_df_row(game, tournament_name, 2019) for game in games_list]
    return game_rows

def read_year(year=2019, division="club-open", links=None):
    """Read a year into a dataframe of games."""
    if links is None:
        print("Getting tournaments...")
        links = year_to_tournaments(year, division)
    game_rows_full = []
    print("Reading tournaments...")
    for link in tqdm(links, position=0):
        tournament_data = requests.get(link)
        tournament_soup = BeautifulSoup(tournament_data.text, 'html.parser')
        game_rows = read_tournament_from_soup(tournament_soup, year)
        game_rows_full.extend(game_rows)
    df = pd.DataFrame(game_rows_full, columns=["TN","GT","GST","BP","D","T","F","H","HSd", "HS","A", "ASd","AS"])
    return df

def get_teams(df):
    """Get a list of all teams in dataframe."""
    teams = df[["H","A"]].melt()["value"].unique()
    index_to_name = dict(enumerate(teams))
    name_to_index = dict([(index_to_name[i], i) for i in index_to_name])
    return teams, index_to_name, name_to_index

def clean_df(df):
    """Cleans dataframe to remove undesirable rows."""
    df = df.fillna("None")
    
    df["HS"] = df["HS"].replace(["W","L","F"], np.nan)
    df["AS"] = df["AS"].replace(["W","L","F"], np.nan)
    # We ignore games that don't have listed score differentials.
    df.dropna(inplace=True)
    df["HS"] = df["HS"].astype(int)
    df["AS"] = df["AS"].astype(int)
    
    df = df[~((df["HS"]==0) & (df["AS"] == 0))]
    # ignore games that were not played (both scores 0)
    df = df.reset_index(drop=True)
    return df

def make_incidence_matrix(df, zerosum=False):
    """Makes incidence matrix and score vector from dataframe."""
    teams, index_to_name, name_to_index = get_teams(df)
    m = len(df)
    n = len(teams)
    A = np.zeros((m,n))
    b = np.zeros((m,1))
    
    for i, row in df.iterrows():
        home = name_to_index[row["H"]]
        away = name_to_index[row["A"]]
        A[i, home] = 1
        A[i, away] = -1
        b[i] = row["HS"] - row["AS"]
        b[i] = b[i] + np.sign(b[i])
        ### GIVES THE WINNING TEAM ONE EXTRA POINT!
    return A,b

def get_sort(ratings, index_to_name):
    """Sorts a rating vector into (team name, rating) tuples."""
    team_ratings = [(index_to_name[i], j.item()) for i,j in enumerate(ratings)]
    return sorted(team_ratings, key=itemgetter(1), reverse=True)  
 
def display_sort_list(sort_list):
    """Displays ranked list of teams from sorted tuple list."""
    for i, tup in enumerate(sort_list):
        print(f"{i+1}. {tup[0]} | {tup[1]*100:.0f}")
        # Ratings multiplied by 100 for readability
    
def find_team(df, team):
    "Utility function: returns all games that a given team played in."
    return df[np.any(df[["H","A"]] == team, axis=1)]
